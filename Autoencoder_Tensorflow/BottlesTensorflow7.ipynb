# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras
import tensorflow as tf
# from keras import layers

from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) == 0:
    print("Not enough GPU hardware devices available")
else:
    config = tf.config.experimental.set_memory_growth(physical_devices[0], True)
print("Num GPUs Available: ", len(physical_devices))
# Out:
# Num GPUs Available:  1
# 2023-06-01 01:27:06.135229: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-06-01 01:27:06.170505: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-01 01:27:06.170891: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2080 with Max-Q Design computeCapability: 7.5
# coreClock: 1.23GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 357.69GiB/s
# 2023-06-01 01:27:06.171064: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2023-06-01 01:27:06.172388: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2023-06-01 01:27:06.173671: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2023-06-01 01:27:06.173884: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2023-06-01 01:27:06.175401: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2023-06-01 01:27:06.176136: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2023-06-01 01:27:06.179086: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-06-01 01:27:06.179184: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-01 01:27:06.179589: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-01 01:27:06.180055: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0

# %%
# tf.debugging.set_log_device_placement(True)       # Will print the log information of every execution of tensorflow, mainly about

# %%
#Size of our input images
# SIZE = 128        # It was this value at the beginning, but the image display was poor. 
SIZE = 224
# SIZE = 228          # It was 224, but in order for the current autoencoder model configuration work adequately, we changed it 228

# %% [markdown]
# # Setting the training and testing datasets

# %% [markdown]
# ImageDataGenerator.flow_from_directory: Takes the path to a directory and generates batches of augmented data.

# %%
batch_size = 15
datagen = ImageDataGenerator(rescale=1./255) # Typically used for data augmentation. Here it is only rescaling the image pixels value to range 0 to 1 in decimals

train_generator = datagen.flow_from_directory(
    "../../Images/BottleStoodUp_atNight/Positive/",     # For home laptop
    # "../../../BottleStoodUp_atNight/Positive/",           # For work laptop
    target_size=(SIZE, SIZE),
    batch_size=batch_size,
    shuffle = False,
    class_mode='input'          # Class used for working with Autoencoders
    
    )
# Out:
# Found 179 images belonging to 1 classes.

# %%
validation_generator = datagen.flow_from_directory(
    "../../Images/BottleStoodUp_atNight/Positive_val/",     # For home laptop
    # "../../../BottleStoodUp_atNight/Positive_val/",           # For work lpatop   
    target_size=(SIZE, SIZE),
    batch_size=batch_size,
    shuffle = False,
    class_mode='input'
    )
# Out:
# Found 30 images belonging to 1 classes.

# %%
anomaly_generator = datagen.flow_from_directory(
    "../../Images/BottleStoodUp_atNight/Anomalies2.0/",         # For home laptop
    # "../../../BottleStoodUp_atNight/Anomalies2.0/",           # For work lpatpo
    target_size=(SIZE, SIZE),
    batch_size=batch_size,
    shuffle = False,
    class_mode='input'
    )
# Out:
# Found 6 images belonging to 1 classes.

# %%
test_set_generator = datagen.flow_from_directory(
    "../../Images/BottleStoodUp_atNight/Evaluation/",       # For home laptop
    # "../../../BottleStoodUp_atNight/Evaluation/",             # For work laptop  
    target_size=(SIZE, SIZE),
    batch_size=batch_size,
    shuffle = False,
    class_mode='input'
    )
# Out:
# Found 30 images belonging to 2 classes.

# %% [markdown]
# # Showing one sample of the training set images

# %% [markdown]
# Grabbing only one image of one batch of the training set.

# %%
images_in_batch = next(train_generator)[0]
print(type(images_in_batch))
print(len(images_in_batch))
print(tf.reduce_min(images_in_batch), tf.reduce_max(images_in_batch))
# Out:
# <class 'numpy.ndarray'>
# 15
# 2023-06-01 01:27:06.572109: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2023-06-01 01:27:06.594685: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2599990000 Hz
# 2023-06-01 01:27:06.595189: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f923c0016b0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-06-01 01:27:06.595233: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-06-01 01:27:06.662197: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-01 01:27:06.662629: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3fca460 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-06-01 01:27:06.662645: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 with Max-Q Design, Compute Capability 7.5
# 2023-06-01 01:27:06.662808: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-01 01:27:06.663128: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2080 with Max-Q Design computeCapability: 7.5
# coreClock: 1.23GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 357.69GiB/s
# 2023-06-01 01:27:06.663164: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2023-06-01 01:27:06.663179: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2023-06-01 01:27:06.663193: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2023-06-01 01:27:06.663206: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2023-06-01 01:27:06.663220: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2023-06-01 01:27:06.663233: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2023-06-01 01:27:06.663247: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-06-01 01:27:06.663302: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-01 01:27:06.663640: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-01 01:27:06.663933: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2023-06-01 01:27:06.663960: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2023-06-01 01:27:06.664391: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-06-01 01:27:06.664403: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2023-06-01 01:27:06.664410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2023-06-01 01:27:06.664500: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-01 01:27:06.664842: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-01 01:27:06.665156: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7005 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5)
# tf.Tensor(0.0, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32)

# %%
print(images_in_batch.shape)
# Out:
# (15, 224, 224, 3)

# %%
single_img = images_in_batch[0]
plt.imshow(single_img)

# %% [markdown]
# # Configuring the Autoencoder netwrok

# %%
#Encoder
model = Sequential()

model.add(Conv2D(128, (13, 13), activation='relu', padding='same', input_shape=(SIZE, SIZE, 3)))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(64, (13, 13), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(32, (13, 13), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(16, (13, 13), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8,(13, 13), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))

#Decoder
model.add(Conv2D(8,(13, 13), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(16, (13, 13), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32,(13, 13), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(64, (13, 13), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(128, (13, 13), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))

model.add(Conv2D(3, (13, 13), activation='sigmoid', padding='same'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 224, 224, 128)     65024
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 112, 112, 128)     0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 112, 112, 64)      1384512
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 56, 56, 32)        346144
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 28, 28, 16)        86544
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 14, 14, 8)         21640
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 7, 7, 8)           10824
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 14, 14, 8)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 14, 14, 16)        21648
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 28, 28, 32)        86560
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 56, 56, 64)        346176
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 112, 112, 128)     1384576
# _________________________________________________________________
# up_sampling2d_9 (UpSampling2 (None, 224, 224, 128)     0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 224, 224, 3)       64899
# =================================================================
# Total params: 3,818,547
# Trainable params: 3,818,547
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # input_img = keras.Input(shape=(28, 28, 1))
# input_img = keras.Input(shape=(SIZE, SIZE, 3))

# # print("ENCODER PART")
# # print("input img shape is: ", input_shape)
# x = keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
# # print("after Conv2D, the shape is: ", x.shape)
# x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)
# # print("after MaxPooling2D, the shape is: ", x.shape)
# x = keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
# # print("after Conv2D, the shape is: ", x.shape)
# x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)
# # print("after MaxPooling2D, the shape is: ", x.shape)
# x = keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
# # print("after Conv2D, the shape is: ", x.shape)
# encoded = keras.layers.MaxPooling2D((2, 2), padding='same')(x)
# # print("after MaxPooling2D, the shape is: ", encoded.shape)

# # at this point the representation is (4, 4, 8) i.e. 128-dimensional

# # print("DECODER PART")
# x = keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
# # print("after Conv2D, the shape is: ", x.shape)
# x = keras.layers.UpSampling2D((2, 2))(x)
# # print("after UpSampling2D, the shape is: ", x.shape)
# x = keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
# # print("after Conv2D, the shape is: ", x.shape)
# x = keras.layers.UpSampling2D((2, 2))(x)
# # print("after UpSampling2D, the shape is: ", x.shape)
# x = keras.layers.Conv2D(16, (3, 3), activation='relu')(x)
# # print("after Conv2D, the shape is: ", x.shape)
# x = keras.layers.UpSampling2D((2, 2))(x)
# # print("after UpSampling2D, the shape is: ", x.shape)
# # decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
# decoded = keras.layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)
# # print("after Conv2D, the shape is: ", decoded.shape)


# autoencoder = keras.Model(input_img, decoded)
# autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
# autoencoder.summary()

# %%
#Fit the model. 
history = model.fit(
        train_generator,
        epochs=200,
        validation_data=validation_generator,
        shuffle = True)
# Out:
# Epoch 1/200
# 2023-06-01 01:27:37.469805: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-06-01 01:27:38.843463: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 12/12 [==============================] - 16s 1s/step - loss: 0.0501 - mse: 0.0501 - val_loss: 0.0375 - val_mse: 0.0375
# Epoch 2/200
# 12/12 [==============================] - 3s 269ms/step - loss: 0.0294 - mse: 0.0294 - val_loss: 0.0204 - val_mse: 0.0204
# Epoch 3/200
# 12/12 [==============================] - 3s 266ms/step - loss: 0.0171 - mse: 0.0171 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 4/200
# 12/12 [==============================] - 3s 267ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 5/200
# 12/12 [==============================] - 3s 268ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 6/200
# 12/12 [==============================] - 3s 266ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 7/200
# 12/12 [==============================] - 3s 269ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 8/200
# 12/12 [==============================] - 3s 268ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 9/200
# 12/12 [==============================] - 3s 269ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 10/200
# 12/12 [==============================] - 3s 267ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 11/200
# 12/12 [==============================] - 3s 266ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 12/200
# 12/12 [==============================] - 3s 269ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 13/200
# 12/12 [==============================] - 3s 269ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 14/200
# 12/12 [==============================] - 3s 268ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 15/200
# 12/12 [==============================] - 3s 274ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 16/200
# 12/12 [==============================] - 3s 269ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 17/200
# 12/12 [==============================] - 3s 269ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 18/200
# 12/12 [==============================] - 3s 270ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 19/200
# 12/12 [==============================] - 3s 272ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 20/200
# 12/12 [==============================] - 3s 271ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 21/200
# 12/12 [==============================] - 3s 271ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 22/200
# 12/12 [==============================] - 3s 271ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 23/200
# 12/12 [==============================] - 3s 270ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 24/200
# 12/12 [==============================] - 3s 270ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 25/200
# 12/12 [==============================] - 3s 270ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 26/200
# 12/12 [==============================] - 3s 273ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 27/200
# 12/12 [==============================] - 3s 270ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 28/200
# 12/12 [==============================] - 3s 269ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 29/200
# 12/12 [==============================] - 3s 270ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 30/200
# 12/12 [==============================] - 3s 270ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 31/200
# 12/12 [==============================] - 3s 272ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 32/200
# 12/12 [==============================] - 3s 270ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 33/200
# 12/12 [==============================] - 3s 272ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 138/200
# 12/12 [==============================] - 3s 234ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 139/200
# 12/12 [==============================] - 3s 235ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 140/200
# 12/12 [==============================] - 3s 238ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 141/200
# 12/12 [==============================] - 3s 235ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 142/200
# 12/12 [==============================] - 3s 235ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 143/200
# 12/12 [==============================] - 3s 234ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 144/200
# 12/12 [==============================] - 3s 236ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 145/200
# 12/12 [==============================] - 3s 236ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 146/200
# 12/12 [==============================] - 3s 234ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 147/200
# 12/12 [==============================] - 3s 239ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 148/200
# 12/12 [==============================] - 3s 234ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 149/200
# 12/12 [==============================] - 3s 234ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 150/200
# 12/12 [==============================] - 3s 235ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 151/200
# 12/12 [==============================] - 3s 235ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 152/200
# 12/12 [==============================] - 3s 236ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 153/200
# 12/12 [==============================] - 3s 234ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 154/200
# 12/12 [==============================] - 3s 234ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 155/200
# 12/12 [==============================] - 3s 235ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 156/200
# 12/12 [==============================] - 3s 236ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 157/200
# 12/12 [==============================] - 3s 234ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 158/200
# 12/12 [==============================] - 3s 234ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0026 - val_mse: 0.0026
# 12/12 [==============================] - 3s 238ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0019 - val_mse: 0.0019

# %%
# Get the training and validation loss values from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot the training and validation loss
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'b-', label='Training Loss')
plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model_version = 'NewAutoencoderModel6'
print(model_version)
# Out:
# NewAutoencoderModel6

# %%
model.save(f"../../BottlesAnomalies_TFM/models/{model_version}")
# Out:
# 2023-06-01 01:46:28.027740: W tensorflow/python/util/util.cc:329] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /home/alexpc/.local/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ../../BottlesAnomalies_TFM/models/NewAutoencoderModel6/assets

# %%
print(type(model))
# Out:
# <class 'tensorflow.python.keras.engine.sequential.Sequential'>

# %% [markdown]
# Loading the model that was previously saved

# %%
model = keras.models.load_model('../models/NewAutoencoderModel6')
print(type(model))
# Out:
# <class 'tensorflow.python.keras.engine.sequential.Sequential'>

# %% [markdown]
# Get all batches generated by the datagen and pick a batch for prediction

# %%
#Just to test the model. 
data_batch = []  #Capture all training batches as a numpy array
img_num = 0
# while img_num <= train_generator.batch_index:   #gets each generated batch of size batch_size
while img_num < len(train_generator):        #I think this should be the correct while clause
    data = train_generator.next()
    data_batch.append(data[0])
    img_num = img_num + 1
    
print("number of batches are: ", img_num)
# Out:
# number of batches are:  12

# %%
print(len(data_batch))
# Out:
# 12

# %% [markdown]
# Predict on the first batch of images. Do also notice that the prediction is being carried out over the images we used for training.

# %%
print(data_batch[0].shape)
predicted = model.predict(data_batch[0])  
print(predicted.shape)
# Out:
# (15, 224, 224, 3)
# (15, 224, 224, 3)

# %% [markdown]
# The above is 15 length because it corresponds to the 15 predicted images of a batch. Recall that the predictions are reconstructions of the input images, since we are working with the autoencoder network.

# %%
#Sanity check, view few images and corresponding reconstructions
image_number = random.randint(0, predicted.shape[0]-1)
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.title("input image")
plt.imshow(data_batch[0][image_number])
plt.subplot(122)
plt.title("reconstructed image")
plt.imshow(predicted[image_number])
plt.show()

# %% [markdown]
# THe reconstructed image is way much better now.

# %% [markdown]
# # Quantifying the reconstruction error

# %% [markdown]
# Let us examine the reconstruction error of our validation data (good/normal images) and the anomaly images

# %%
validation_error = model.evaluate_generator(validation_generator)
print("Recon. error for the validation (normal) data is: ", validation_error)
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_72299/2207300971.py:1: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# Recon. error for the validation (normal) data is:  0.6153973937034607

# %% [markdown]
# Here above we see a vector with two components which happen to be the same between them. This is because in the model, when we define the outputs, the loss function type and the metric are the same parameter, the mse (mean square error).

# %% [markdown]
# This reconstruction error above should be very low, since the validation generator is full of normal images (good images)

# %% [markdown]
# Whereas the reconstruction error here below, for the "anomaly_generator" should be higher, since this dataset is comprised of full anomaly images.

# %%
anomaly_error = model.evaluate_generator(anomaly_generator)
print("Recon. error for the anomaly data is: ", anomaly_error)
# Out:
# Recon. error for the anomaly data is:  0.6051943302154541

# %% [markdown]
# See that this error is slightly higher than the error in the validation dataset. This is good, but the difference is not that significant and this could result in wrong anomaly detections. Let's see some detections.

# %% [markdown]
# SIDENOTE: Additionally, we can check the train generator error according to the "evaluate_generator()" function.

# %%
training_error = model.evaluate_generator(train_generator)
print("Recon. error for the training (non-anomaly) data is: ", training_error)
# Out:
# Recon. error for the training (non-anomaly) data is:  0.6100006699562073

# %% [markdown]
# See that the above value does not correspond with the below mean reconstruction error of the training set that will be computed. It should at least be close, I think. This is something to check.

# %% [markdown]
# # Computing the reconstruction error without using the "evaluate_generator()" function

# %% [markdown]
# The following function computes the reconstrution error per each batch of images. It does, for each of the batches:
# - Initialize a vector for storing the reconstruction errors.
# - A for loop that traverses all the images contained in a batch.
#     - Take the one image of the batch.
#     - Add a new size dimension to the image.
#     - Make a prediction of the selected image with the model that was built.
#     - Evaluate the performance of the prediction, i.e. compute the prediction error.
#     - Append the reconstruction error into a list.
# - Compute the mean and std deviation of the error.

# %%
def calc_recon_error(batch_images):   
    recon_error_list=[]
    for im in range(0, batch_images.shape[0]):
        img  = batch_images[im]
        img = img[np.newaxis, :,:,:]
        reconstruction = model.predict([[img]])
        # reconstruction_error = model.evaluate([reconstruction],[[img]], batch_size = 1)[0]    # The batch_size parameter for the moment can be supressed. Results were seen to be the same
        # reconstruction_error = model.evaluate([reconstruction],[[img]])[0]                    # It included the [0] subscription but with this new model, the rec error is directly a float value, so no more need for subscription
        reconstruction_error = model.evaluate([reconstruction],[[img]])
        recon_error_list.append(reconstruction_error)   
    return recon_error_list

# %%
total_rec_error = []
for i in range(len(train_generator)):        #I think this should be the correct while clause
    data = train_generator.next()
    total_rec_error.append(calc_recon_error(data[0]))
    
print("The list of rec. error contains ", len(total_rec_error), "batches of rec. errors")
# Out:
# 1/1 [==============================] - 0s 797us/step - loss: 0.6100
# 1/1 [==============================] - 0s 842us/step - loss: 0.6177
# 1/1 [==============================] - 0s 820us/step - loss: 0.5864
# 1/1 [==============================] - 0s 945us/step - loss: 0.5845
# 1/1 [==============================] - 0s 909us/step - loss: 0.5887
# 1/1 [==============================] - 0s 899us/step - loss: 0.5931
# 1/1 [==============================] - 0s 824us/step - loss: 0.5870
# 1/1 [==============================] - 0s 857us/step - loss: 0.5786
# 1/1 [==============================] - 0s 932us/step - loss: 0.5744
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5690
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6065
# 1/1 [==============================] - 0s 839us/step - loss: 0.6159
# 1/1 [==============================] - 0s 970us/step - loss: 0.6134
# 1/1 [==============================] - 0s 787us/step - loss: 0.6122
# 1/1 [==============================] - 0s 957us/step - loss: 0.6129
# 1/1 [==============================] - 0s 954us/step - loss: 0.5994
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6029
# 1/1 [==============================] - 0s 756us/step - loss: 0.5997
# 1/1 [==============================] - 0s 971us/step - loss: 0.5962
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5881
# 1/1 [==============================] - 0s 667us/step - loss: 0.5894
# 1/1 [==============================] - 0s 704us/step - loss: 0.5806
# 1/1 [==============================] - 0s 711us/step - loss: 0.5833
# The list of rec. error contains  12 batches of rec. errors

# %%
print(type(total_rec_error[0]))
# Out:
# <class 'list'>

# %%
total_rec_error_list = [item for sublist in total_rec_error for item in sublist]
print(len(total_rec_error_list))
# Out:
# 179

# %%
na_average_recon_error = np.mean(np.array(total_rec_error_list))  
na_stdev_recon_error = np.std(np.array(total_rec_error_list)) 
min_prob = np.min(total_rec_error_list)
max_prob = np.max(total_rec_error_list)
print("THIS IS FOR THE TRAINING (NON-ANOMALY) IMAGES\n")
print("The average of the errors list is: ", na_average_recon_error)
print("The standard deviation of the errors list is: ", na_stdev_recon_error)
print("The min value of the errors list is: ", min_prob)
print("The max value of the errors list is: ", max_prob)
# Out:
# THIS IS FOR THE TRAINING (NON-ANOMALY) IMAGES
#
# The average of the errors list is:  0.6115124878270666
# The standard deviation of the errors list is:  0.011979443425860227
# The min value of the errors list is:  0.566664457321167
# The max value of the errors list is:  0.6208344101905823

# %% [markdown]
# Compute the average and std dev. of recon. error for positive (anomalies) samples.

# %%
anomaly_batch = anomaly_generator.next()

# %%
total_rec_error_anomalies = []
data = anomaly_generator.next()
total_rec_error_anomalies=calc_recon_error(data[0])
print(len(total_rec_error_anomalies))
# Out:
# 1/1 [==============================] - 0s 610us/step - loss: 0.6167
# 1/1 [==============================] - 0s 726us/step - loss: 0.6200
# 1/1 [==============================] - 0s 703us/step - loss: 0.6173
# 1/1 [==============================] - 0s 648us/step - loss: 0.5686
# 1/1 [==============================] - 0s 849us/step - loss: 0.6148
# 1/1 [==============================] - 0s 650us/step - loss: 0.6032
# 6

# %%
a_average_recon_error = np.mean(np.array(total_rec_error_anomalies))  
a_stdev_recon_error = np.std(np.array(total_rec_error_anomalies)) 
min_prob = np.min(total_rec_error_anomalies)
max_prob = np.max(total_rec_error_anomalies)
print("THIS IS FOR THE ANOMALY IMAGES\n")
print("The average of the errors list is: ", a_average_recon_error)
print("The standard deviation of the errors list is: ", a_stdev_recon_error)
print("The min value of the errors list is: ", min_prob)
print("The max value of the errors list is: ", max_prob)
# Out:
# THIS IS FOR THE ANOMALY IMAGES
#
# The average of the errors list is:  0.6067801713943481
# The standard deviation of the errors list is:  0.01788957845995917
# The min value of the errors list is:  0.5685976147651672
# The max value of the errors list is:  0.6200035810470581

# %% [markdown]
# See above that results are alreayd shit. The average reconstruction error for non-anomaly images is hihgher than the average for anomaly images

# %% [markdown]
# Below, we can see the plot of the reconstruction error values, of the non-anomaly list (blue) and the anomaly list (red).

# %%
plt.figure(figsize=(10, 10))
val = 0. # this is the value where you want the data to appear on the y-axis.
plt.plot(total_rec_error_list, np.zeros_like(total_rec_error_list) + val, 'x')
plt.plot(total_rec_error_anomalies, np.zeros_like(total_rec_error_anomalies) + val, 'ro')
plt.show()

# %% [markdown]
# AT THIS POINT THE TEST COULD END. The reuslts are already worthless.
