# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras

from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
#Size of our input images
SIZE = 128

# %% [markdown]
# # Setting the training and testing datasets

# %% [markdown]
# ImageDataGenerator.flow_from_directory: Takes the path to a directory & generates batches of augmented data.

# %%
batch_size = 64
datagen = ImageDataGenerator(rescale=1./255) # Typically used for data augmentation. Here it is only rescaling the image pixels value to range 0 to 1 in decimals

train_generator = datagen.flow_from_directory(
    # "../../Images/BottleStoodUp_atNight/Positive/",
    "../../../BottleStoodUp_atNight/Positive/",
    target_size=(SIZE, SIZE),
    batch_size=batch_size,
    class_mode='input'          # Class used for working with Autoencoders
    )
# Out:
# Found 179 images belonging to 1 classes.

# %%
validation_generator = datagen.flow_from_directory(
    "../../../BottleStoodUp_atNight/Positive_val/",
    target_size=(SIZE, SIZE),
    batch_size=batch_size,
    class_mode='input'
    )
# Out:
# Found 30 images belonging to 1 classes.

# %%
anomaly_generator = datagen.flow_from_directory(
    "../../../BottleStoodUp_atNight/Anomalies/",
    target_size=(SIZE, SIZE),
    batch_size=batch_size,
    class_mode='input'
    )
# Out:
# Found 6 images belonging to 1 classes.

# %% [markdown]
# # Checking the generators

# %% [markdown]
# See the sizes of each generator. Notice that the last one, does not contain any sample because we do not have negative samples, that is anomalies.

# %%
print("The training dataset has size: ", len(train_generator))
print("The training dataset has size: ", len(validation_generator))
print("The training dataset has size: ", len(anomaly_generator))
# Out:
# The training dataset has size:  3
# The training dataset has size:  1
# The training dataset has size:  1

# %% [markdown]
# The sizes above shown correspond to the number of bathces each of the generator contains. Recall that each batch size is of 64 elements.

# %% [markdown]
# ## Iterating over the generators

# %%
batch_iterator = train_generator.next()
print(type(batch_iterator))
print(len(batch_iterator))
# print(batch_iterator)
# Out:
# <class 'tuple'>
# 2

# %% [markdown]
# As one batch length is of two. Let's see what each of these two elements consist of.

# %%
first_element = batch_iterator[0]
second_element = batch_iterator[1]
print(type(first_element))
print(first_element.shape)
print("******************")
print(type(second_element))
print(second_element.shape)
# Out:
# <class 'numpy.ndarray'>
# (64, 128, 128, 3)
# ******************
# <class 'numpy.ndarray'>
# (64, 128, 128, 3)

# %% [markdown]
# See that each of the elements correspond to a "group" of 51 or 64 elements, where there are data of images of shape (128, 128) and finally each of these elements consist of 3 channels.
#
# The curious part is that depending on which batch of the generator is chosen (executing the code that has the "next()" function) the length of the elements of contained in that batch vary between 51 and 64. It was expected always it to be 64, because it was set the batch size to be of 64 elements.
#
# Moreover, another question is: why when retrieving a batch, this one contains two elements? It was expected only to be one single element.

# %% [markdown]
# This is another way to use the "next()" function.

# %%
batch_iterator2 = next(train_generator)
print(type(batch_iterator2))
print(len(batch_iterator2))
# Out:
# <class 'tuple'>
# 2

# %% [markdown]
# And also another way to directly enter one of the elements contained in the retrieved batch.

# %%
batch_iterator2 = next(train_generator)[1]
print(type(batch_iterator2))
print(batch_iterator2.shape)
# Out:
# <class 'numpy.ndarray'>
# (51, 128, 128, 3)

# %%
for i in range(1):
    aux = next(train_generator)[0]
    print(type(aux))
    print(aux.shape)
    print(len(aux))
# Out:
# <class 'numpy.ndarray'>
# (64, 128, 128, 3)
# 64

# %% [markdown]
# What "astype()" above does, is simply to convery the image data matrix from float values to be integers.

# %% [markdown]
# Now we will show the images contained in the batches.
#
# Showing the images contained in only one batch. And from this batch, showing the images contained in both of its elements. The first element images are shown below:

# %%
plt.figure(figsize=(10, 10))
for j in range(1):                        # Itertaing over ONLY the first batch
    print("Selecting batch number: ",j)
    batch_iterator = train_generator.next()
    first_element_batch = batch_iterator[0]
    second_element_batch = batch_iterator[1]
    print("This is the element number 1 of the batch")
    print("The length of this element batch is: ", len(first_element_batch))
    for i in range(12):                         # Showing ONLY the first 12 samples of the batch
        plt.subplot(3, 4, i + 1)
        plt.imshow(first_element_batch[i])
# Out:
# Selecting batch number:  0
# This is the element number 1 of the batch
# The length of this element batch is:  64

# %% [markdown]
# And now, the second element images:

# %%
plt.figure(figsize=(10, 10))
for j in range(1):                        # Itertaing over ONLY the first batch
    print("Selecting batch number: ",j)
    print("This is the element number 2 of the batch")
    print("The length of this element batch is: ", len(second_element_batch))
    for i in range(12):                         # Showing ONLY the first 12 samples of the batch
        plt.subplot(3, 4, i + 1)
        plt.imshow(second_element_batch[i])
# Out:
# Selecting batch number:  0
# This is the element number 2 of the batch
# The length of this element batch is:  64

# %% [markdown]
# Here, showing the images from the first and second element of the batch side by side.

# %%
plt.figure(figsize=(20, 20))
for j in range(1):                        # Itertaing over ONLY the first batch
    print("Selecting batch number: ",j)
    batch_iterator = train_generator.next()
    first_element_batch = batch_iterator[0]
    second_element_batch = batch_iterator[1]
    print("The length of this element batch is: ", len(first_element_batch))
    image_to_show = 0
    for i in range(12):                         # Showing ONLY the first 12 samples of the batch
        plt.subplot(3, 4, i + 1)
        if (i % 2 == 0):
            plt.imshow(first_element_batch[image_to_show])
            plt.title("First element, img: %i" %image_to_show)
        else:
            plt.imshow(second_element_batch[image_to_show])
            plt.title("Second element, img: %i" %image_to_show)
            image_to_show = image_to_show+1
# Out:
# Selecting batch number:  0
# The length of this element batch is:  51

# %% [markdown]
# See that the images of each element of the batch are pretty similar, if not the same. This might be due to the fact that the image generator function only rescales the image pixels to float values ranging from 0 to 1.
#
# <code> datagen = ImageDataGenerator(rescale=1./255) # Typically used for data augmentation. Here it is only rescaling the image pixels value to range 0 to 1 in decimals </code>

# %% [markdown]
# Next, it is interesting to know until which point the next() function of the DataGeneration class can go.

# %%
print("The size of the train generator is: ", len(train_generator))
# Out:
# The size of the train generator is:  3

# %%
print("The current index of the train generator is: ", train_generator.batch_index)
# Out:
# The current index of the train generator is:  0

# %%
i = 0
for batch_iterator in range(7):
    print("The current index of the train generator is: ", train_generator.batch_index)
    train_generator.next()
    print("External counter is: ", i)
    i=i+1
    print("\n")
# Out:
# The current index of the train generator is:  0
# External counter is:  0
#
#
# The current index of the train generator is:  1
# External counter is:  1
#
#
# The current index of the train generator is:  2
# External counter is:  2
#
#
# The current index of the train generator is:  0
# External counter is:  3
#
#
# The current index of the train generator is:  1
# External counter is:  4
#
#
# The current index of the train generator is:  2
# External counter is:  5
#
#
# The current index of the train generator is:  0
# External counter is:  6

# %% [markdown]
# From above, it can be seen that the "next()" function works as expected. It iterates over the possible indexes it can take.

# %% [markdown]
# ## Trying with augmented data

# %% [markdown]
# It was believed that the first and second element of the batch are the same image because the data augmentation that we had for the example consisted only on rescaling the pixel values. In this section different data augmentation will be tested.

# %%
batch_size = 64
datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True, vertical_flip=True) # Typically used for data augmentation. Here it is  rescaling the image pixels value to range 0 to 1 in decimals and applying horizontal and vertical flip

train_generator = datagen.flow_from_directory(
    "../../../BottleStoodUp_atNight/Positive/",
    target_size=(SIZE, SIZE),
    batch_size=batch_size,
    class_mode='input'          # Class used for working with Autoencoders
    )
# Out:
# Found 179 images belonging to 1 classes.

# %%
plt.figure(figsize=(20, 20))
for j in range(1):                        # Itertaing over ONLY the first batch
    print("Selecting batch number: ",j)
    batch_iterator = train_generator.next()
    first_element_batch = batch_iterator[0]
    second_element_batch = batch_iterator[1]
    print("The length of this element batch is: ", len(first_element_batch))
    image_to_show = 0
    for i in range(12):                         # Showing ONLY the first 12 samples of the batch
        plt.subplot(3, 4, i + 1)
        if (i % 2 == 0):
            plt.imshow(first_element_batch[image_to_show])
            plt.title("First element, img: %i" %image_to_show)
        else:
            plt.imshow(second_element_batch[image_to_show])
            plt.title("Second element, img: %i" %image_to_show)
            image_to_show = image_to_show+1
# Out:
# Selecting batch number:  0
# The length of this element batch is:  64

# %% [markdown]
# Notice that the flipping of the data augmentation made its effect on the images, however the following is worth mentioning:
# - The flipping is not applied to all images. See the second and fourth images, these did not get flipped.
# - Still the first and second element are the same. It means that the effect of the data augmentation is directly applied to both elements. Hence, we still don't know why we have these two elements of a batch. Only one element was expected.
# - Finally, we still don't know why sometimes the length of the batch is 51.

# %% [markdown]
# # Configuring the Autoencoder netwrok

# %%
#Encoder
model = Sequential()
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(SIZE, SIZE, 3)))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))

#Decoder
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))

model.add(Conv2D(3, (3, 3), activation='sigmoid', padding='same'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 16)        2320
#
#  up_sampling2d (UpSampling2D  (None, 32, 32, 16)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 32)        4640
#
#  up_sampling2d_1 (UpSampling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)        18496
#
#  up_sampling2d_2 (UpSampling  (None, 128, 128, 64)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 3)       1731
#
# =================================================================
# Total params: 52,067
# Trainable params: 52,067
# Non-trainable params: 0
# _________________________________________________________________

# %%
500//64
# Out:
# 7

# %%
#Fit the model. 
history = model.fit(
        train_generator,
        steps_per_epoch= 500 // batch_size,     # The // operator refers to a floor division, rouding down to the nearest whole number
        epochs=200,
        validation_data=validation_generator,
        validation_steps=75 // batch_size,
        shuffle = True)
# Out:
# Epoch 1/200
# 3/7 [===========>..................] - ETA: 5s - loss: 0.0403 - mse: 0.0403WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 1400 batches). You may need to use the repeat() function when building your dataset.
# 7/7 [==============================] - 8s 823ms/step - loss: 0.0403 - mse: 0.0403 - val_loss: 0.0375 - val_mse: 0.0375

# %% [markdown]
# See that above, the training of the model is stopped because the trainig generator did not provide the minimum number of batches for it to be trained. According to the message displayed above, the model expects at least 1400 batches.
#
# Let's try another configuration for the model training. Here, we don't specify the steps per epoch. Resulting in a three-step long epoch, because the entire training model contains 3 batches.

# %%
#Fit the model. 
history = model.fit(
        train_generator,
        epochs=200,
        validation_data=validation_generator,
        shuffle = True)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0376 - mse: 0.0376 - val_loss: 0.0337 - val_mse: 0.0337
# Epoch 2/200
# 3/3 [==============================] - 5s 2s/step - loss: 0.0308 - mse: 0.0308 - val_loss: 0.0257 - val_mse: 0.0257
# Epoch 3/200
# 3/3 [==============================] - 5s 2s/step - loss: 0.0270 - mse: 0.0270 - val_loss: 0.0219 - val_mse: 0.0219
# Epoch 4/200
# 3/3 [==============================] - 5s 2s/step - loss: 0.0213 - mse: 0.0213 - val_loss: 0.0205 - val_mse: 0.0205
# Epoch 5/200
# 3/3 [==============================] - 5s 2s/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 6/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 7/200
# 3/3 [==============================] - 5s 2s/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 8/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 9/200
# 3/3 [==============================] - 5s 2s/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 10/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 11/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 12/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 13/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 14/200
# 3/3 [==============================] - 5s 2s/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 15/200
# 3/3 [==============================] - 5s 2s/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 16/200
# 3/3 [==============================] - 5s 2s/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 17/200
# 3/3 [==============================] - 5s 2s/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 18/200
# 3/3 [==============================] - 5s 2s/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 19/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 20/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 21/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 22/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 23/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 24/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 25/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 26/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 27/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 28/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 29/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 30/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 31/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 32/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 33/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 34/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 35/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 36/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 37/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 38/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 39/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 40/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 41/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 42/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 43/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 44/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 45/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 46/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 47/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 48/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 49/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 50/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 51/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 52/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 53/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 54/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 55/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 56/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 57/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 58/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 59/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 60/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 61/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 62/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 63/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 64/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 65/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 66/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 67/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 68/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 69/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 70/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 71/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 72/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 73/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 74/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 75/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 76/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 77/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 78/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 79/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 80/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 81/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 82/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 83/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 84/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 85/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 86/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 87/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 88/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 89/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 90/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 91/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 92/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 93/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 94/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 95/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 96/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 97/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 98/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 99/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 100/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 101/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 102/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 103/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 104/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 105/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 106/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 107/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 108/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 109/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 110/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 111/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 112/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 113/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 114/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 115/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 116/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 117/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 118/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 119/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 120/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 121/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 122/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 123/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 124/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 125/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 126/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 127/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 128/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 129/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 130/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 131/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 132/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 133/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 134/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 135/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 136/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 137/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 138/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 139/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 140/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 141/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 142/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 143/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 144/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 145/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 146/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 147/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 148/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 149/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 150/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 151/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 152/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 153/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 154/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 155/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 156/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 157/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 158/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 159/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 160/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 161/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 162/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 163/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 164/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 165/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 166/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 167/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 168/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 169/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 170/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 171/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 172/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 173/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 174/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 175/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 176/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 177/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 178/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 179/200
# 3/3 [==============================] - 7s 3s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 180/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 181/200
# 3/3 [==============================] - 8s 3s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 182/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 183/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 184/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 185/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 186/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 187/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 188/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 189/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 190/200
# 3/3 [==============================] - 8s 2s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 191/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 192/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 193/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 194/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 195/200
# 3/3 [==============================] - 6s 2s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 196/200
# 3/3 [==============================] - 8s 3s/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 197/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 198/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 199/200
# 3/3 [==============================] - 8s 3s/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 200/200
# 3/3 [==============================] - 7s 2s/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0028 - val_mse: 0.0028

# %% [markdown]
# According to the Keras documentation, as a paremeter to the fit() function, we can also pass a generator for its two first parameters. See the image below. See more references: <https://keras.io/api/models/model_training_apis/>
#
# ![alt text](../Image5.png "Title")

# %%
model_version = 'BottlesModel1'
model.save(f"../../BottlesAnomalies_TFM/models/{model_version}")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../../BottlesAnomalies_TFM/models/BottlesModel1\assets
# INFO:tensorflow:Assets written to: ../../BottlesAnomalies_TFM/models/BottlesModel1\assets

# %% [markdown]
# Loading the model that was previously saved

# %%
model = keras.models.load_model('../models/BottlesModel1')
print(type(model))
# Out:
# <class 'keras.engine.sequential.Sequential'>

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 #plot the training and validation accuracy and loss at each epoch
# ----> 2 loss = history.history['loss']
#       3 val_loss = history.history['val_loss']
#       4 epochs = range(1, len(loss) + 1)
#
# NameError: name 'history' is not defined

# %% [markdown]
# The above won't be possible to show if we are loading the model. Because the data that is stored while training the model won't be stored when loading the model at once.

# %% [markdown]
# Get all batches generated by the datagen and pick a batch for prediction

# %%
#Just to test the model. 
data_batch = []  #Capture all training batches as a numpy array
img_num = 0
while img_num <= train_generator.batch_index:   #gets each generated batch of size batch_size
# while img_num <= len(train_generator):        #I think this should be the correct while clause
    data = train_generator.next()
    data_batch.append(data[0])
    img_num = img_num + 1
    
print("number of batches are: ", img_num)
# Out:
# number of batches are:  3

# %% [markdown]
# Predict on the first batch of images. Do also notice that the prediction is being carried out over the images we used for training.

# %%
print(data_batch[0].shape)
# Out:
# (64, 128, 128, 3)

# %%
predicted = model.predict(data_batch[0])
# Out:
# 2/2 [==============================] - 1s 193ms/step

# %%
predicted.shape
# Out:
# (64, 128, 128, 3)

# %% [markdown]
# The above is 64 length because it corresponds to the 64 predicted images of a batch. Recall that the predictions are reconstructions of the input images, since we are working with the autoencoder network.

# %%
#Sanity check, view few images and corresponding reconstructions
image_number = random.randint(0, predicted.shape[0])
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.title("input image")
plt.imshow(data_batch[0][image_number])
plt.subplot(122)
plt.title("reconstructed image")
plt.imshow(predicted[image_number])
plt.show()

# %% [markdown]
# As it can be seen above, the reconstruction is not that good, it is very blurry. However, we can see to generate negative artificial samples and see if these are capable of being detected as such.

# %% [markdown]
# Let us examine the reconstruction error between our validation data (good/normal images) and the anomaly images

# %%
validation_error = model.evaluate_generator(validation_generator)
print("Recon. error for the validation (normal) data is: ", validation_error)
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_16916\2207300971.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   validation_error = model.evaluate_generator(validation_generator)
# Recon. error for the validation (normal) data is:  [0.0027755312621593475, 0.0027755312621593475]

# %% [markdown]
# Here above we see a vector with two components which happen to be the same between them. This is because in the model, when we define the outputs, the loss function type and the metric are the same parameter, the mse (mean square error).

# %% [markdown]
# This reconstruction error above should be very low, since the validation generator is full of normal images (good images)

# %% [markdown]
# Whereas the reconstruction error here below, for the "anomaly_generator" should be higher, since this dataset is comprised of full anomaly images.

# %%
anomaly_error = model.evaluate_generator(anomaly_generator)
print("Recon. error for the anomaly data is: ", anomaly_error)
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_16916\4089772597.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   anomaly_error = model.evaluate_generator(anomaly_generator)
# Recon. error for the anomaly data is:  [0.002812065416947007, 0.002812065416947007]

# %% [markdown]
# See that this error is slightly higher than the error in the validation dataset. This is good, but the difference is not that significant and this could result in wrong anomaly detections. Let's see some detections.

# %% [markdown]
# The following function performs:
# - Initialize a vector for storing the reconstruction errors.
# - A for loop that traverses all the images contained in a batch.
#     - Take the one image of the batch.
#     - Add a new size dimension to the image.
#     - Make a prediction of the selected image with the model that was built.
#     - Evaluate the performance of the prediction, i.e. compute the prediction error.
#     - Append the reconstruction error into a list.
# - Compute the mean and std deviation of the error.

# %%
def calc_recon_error(batch_images):   
    recon_error_list=[]
    for im in range(0, batch_images.shape[0]-1):
        img  = batch_images[im]
        img = img[np.newaxis, :,:,:]
        reconstruction = model.predict([[img]])
        reconstruction_error = model.evaluate([reconstruction],[[img]], batch_size = 1)[0]
        recon_error_list.append(reconstruction_error)   
    average_recon_error = np.mean(np.array(recon_error_list))  
    stdev_recon_error = np.std(np.array(recon_error_list)) 
    
    return average_recon_error, stdev_recon_error

# %% [markdown]
# # Testing the "calc_recon_error" function part by part the function

# %% [markdown]
# For convinience make sure we are considering the firt batch, i.e the batch index 0.

# %%
train_batch = train_generator.next()
print(train_generator.batch_index)
# Out:
# 0

# %%
train_batch = train_batch[0]
print(train_batch.shape)
# Out:
# (51, 128, 128, 3)

# %%
image = train_batch[0]
print(image.shape)
# Out:
# (128, 128, 3)

# %%
image = image[np.newaxis, :,:,:]
print(image.shape)
# Out:
# (1, 128, 128, 3)

# %%
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
print(type([[image]]))
# Out:
# <class 'list'>

# %% [markdown]
# We can perform the predict functino with either of these two formats. Giving the image parameter as a numpy array or as a list.

# %%
reconstruction = model.predict(image)
# Out:
# 1/1 [==============================] - 0s 36ms/step

# %%
reconstruction = model.predict([[image]])
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %% [markdown]
# Now we evaluate the model performance by using the "evaluate()" function. This receives:
# - The predicted output. We are sending this parameter as a list. It could also be sent as numpy array.
# - The original image. Also sent as a list.
# - The batch size. Refers to the number of samples per batch of computation. However, see that the result is the same when not specifying this parameter.
#     - Further check the effect of this parameter.

# %%
reconstruction_error = model.evaluate([reconstruction],[[image]])
print(reconstruction_error)
# Out:
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0063 - mse: 0.0063
# [0.006316961720585823, 0.006316961720585823]

# %%
reconstruction_error = model.evaluate([reconstruction],[[image]], batch_size = 1)
print(reconstruction_error)
# Out:
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0063 - mse: 0.0063
# [0.006316961720585823, 0.006316961720585823]

# %% [markdown]
# # Continuing with the usage of "calc_recon_error" function

# %% [markdown]
# Compute the average and std dev. of recon. error for positive (anomalies) and negative samples.
# For this let us generate a batch of images for each.

# %% [markdown]
# Make sure the first batch is selected for both, train and anomaly batches. For the anomalies case, notice that is not important to check this, since the anomaly dataset contains one batch only. For the train batch make sure to execute the below code block until the batch index is at 2, so that the next execution will select the batch index number 0.

# %%
train_batch = train_generator.next()
print(train_generator.batch_index)
# Out:
# 2

# %%
anomaly_batch = anomaly_generator.next()
print(anomaly_generator.batch_index)
# Out:
# 0

# %%
train_batch = train_generator.next()[0]     # This is the uninfected images
anomaly_batch = anomaly_generator.next()[0] # This is the parasitized images

good_samples_values = calc_recon_error(train_batch)
anomaly_values = calc_recon_error(anomaly_batch)
# Out:
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0052 - mse: 0.0052
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0075 - mse: 0.0075
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0059 - mse: 0.0059
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0060 - mse: 0.0060
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0057 - mse: 0.0057
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0053 - mse: 0.0053
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0059 - mse: 0.0059
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0060 - mse: 0.0060
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0061 - mse: 0.0061
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0060 - mse: 0.0060
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0060 - mse: 0.0060
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0059 - mse: 0.0059
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0061 - mse: 0.0061
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0060 - mse: 0.0060
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0061 - mse: 0.0061
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0059 - mse: 0.0059
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0059 - mse: 0.0059
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0059 - mse: 0.0059
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0059 - mse: 0.0059
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0062 - mse: 0.0062
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0056 - mse: 0.0056
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0060 - mse: 0.0060
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0062 - mse: 0.0062
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0057 - mse: 0.0057
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0059 - mse: 0.0059
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0076 - mse: 0.0076
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0053 - mse: 0.0053
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0070 - mse: 0.0070
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0056 - mse: 0.0056
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0061 - mse: 0.0061
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0061 - mse: 0.0061
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0057 - mse: 0.0057
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0062 - mse: 0.0062
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0057 - mse: 0.0057
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0065 - mse: 0.0065
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0059 - mse: 0.0059
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0061 - mse: 0.0061
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0061 - mse: 0.0061
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0060 - mse: 0.0060
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0059 - mse: 0.0059
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0059 - mse: 0.0059
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0055 - mse: 0.0055
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0061 - mse: 0.0061
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0056 - mse: 0.0056

# %%
print("The mean reconstruction error value for the good samples is: ", good_samples_values[0], " with std deviation of: ", good_samples_values[1])
print("The mean reconstruction error value for the anomalies samples is: ", anomaly_values[0], " with std deviation of: ", anomaly_values[1])
# Out:
# The mean reconstruction error value for the good samples is:  0.005979275405406952  with std deviation of:  0.00041856520477400654
# The mean reconstruction error value for the anomalies samples is:  0.005819786991924048  with std deviation of:  0.00020107349163382086

# %% [markdown]
# Based on the information shown above, we can set a threshold for discriminating good samples from anomalies ones.

# %% [markdown]
# The following function does:
# - Sets the reconstruction error threshold.
# - Opens the given image path.
# - Resizes the image

# %%
#Now, input unknown images and sort as Good or Anomaly
def check_anomaly(img_path):
    reconstruction_error_threshold = 0.006 # Set this value based on the above exercise
    img  = Image.open(img_path)
    img = np.array(img.resize((128,128), Image.ANTIALIAS))
    image_shape = img.shape
    if(len(image_shape)==2):
        img = np.dstack((img, img, img))
    plt.imshow(img)
    img = img / 255.
    print(img.shape)
    img = img[np.newaxis, :,:,:]
    
    reconstruction = model.predict([[img]])
    reconstruction_error = model.evaluate([reconstruction],[[img]], batch_size = 1)[0]

    if reconstruction_error > reconstruction_error_threshold:
        print("The image IS an anomaly") 
    else:
        print("The image is NOT an anomaly")

# %%
#Load a couple of test images and verify whether they are reported as anomalies.
import glob
anomaly_file_paths = glob.glob(r'C:\Users\Alex\Documents\BottleStoodUp_atNight\Anomalies\Anomalies_samples\*')
positive_file_paths = glob.glob(r'C:\Users\Alex\Documents\BottleStoodUp_atNight\Positive\Positive_samples\*')

# %% [markdown]
# # Testing part by part the "check_anomaly" function

# %%
positive_file_paths[0]
# Out:
# 'C:\\Users\\Alex\\Documents\\BottleStoodUp_atNight\\Positive\\Positive_samples\\07-03-2023 - 22.28.40_0.bmp'

# %%
img  = Image.open(positive_file_paths[0]) 
print("The original image size is: ", img.size)
print("The image datatype is: ", type(img))
# Out:
# The original image size is:  (1600, 1200)
# The image datatype is:  <class 'PIL.BmpImagePlugin.BmpImageFile'>

# %% [markdown]
# After reading the image, we resize it using a resampling filter of "Image.ANTIALIAS". The resizing filter is used in geometry operations that may map multiple input pixels to a single output pixel.

# %%
img = np.array(img.resize((128,128), Image.ANTIALIAS))
print("The image after resizing has size: ", img.shape)
print("The image type is also converted to: ", type(img))
# Out:
# The image after resizing has size:  (128, 128)
# The image type is also converted to:  <class 'numpy.ndarray'>
# C:\Users\Alex\AppData\Local\Temp\ipykernel_16916\556291113.py:1: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = np.array(img.resize((128,128), Image.ANTIALIAS))

# %%
plt.imshow(img)
plt.title("Resized image and converted into numpy array")
# Out:
# Text(0.5, 1.0, 'Resized image and converted into numpy array')

# %% [markdown]
# From the image shown above it can be noticed that the picture does not have the 3 channels that it needs for the further training process. It is expected to fail in the prediction stage later in the code, since the input layer of the model consists of 4 elements.

# %% [markdown]
# Converting the pixel values to floating values ranging from 0 to 1.

# %%
img = img / 255.
print("The image after pixel converting the values has size: ", img.shape)
# Out:
# The image after pixel converting the values has size:  (128, 128)

# %%
img = img[np.newaxis,:,:]
print("The image shape after an additional dimension is added, is: ", img.shape)
# Out:
# The image shape after an additional dimension is added, is:  (1, 128, 128)

# %%
reconstruction = model.predict([[img]])
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 reconstruction = model.predict([[img]])
#
# File c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\Alex\.conda\envs\tfm\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sequential/conv2d/Relu' defined at (most recent call last):
#     File "c:\Users\Alex\.conda\envs\tfm\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "c:\Users\Alex\.conda\envs\tfm\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#       app.start()
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\ipykernel\kernelapp.py", line 711, in start
#       self.io_loop.start()
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\Alex\.conda\envs\tfm\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "c:\Users\Alex\.conda\envs\tfm\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "c:\Users\Alex\.conda\envs\tfm\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\ipykernel\ipkernel.py", line 411, in do_execute
#       res = shell.run_cell(
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\ipykernel\zmqshell.py", line 531, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\IPython\core\interactiveshell.py", line 2961, in run_cell
#       result = self._run_cell(
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\IPython\core\interactiveshell.py", line 3016, in _run_cell
#       result = runner(coro)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\IPython\core\interactiveshell.py", line 3221, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\IPython\core\interactiveshell.py", line 3400, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\Alex\AppData\Local\Temp\ipykernel_16916\2209062161.py", line 1, in <module>
#       reconstruction = model.predict([[img]])
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\engine\training.py", line 2350, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\engine\training.py", line 2137, in predict_function
#       return step_function(self, iterator)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\engine\training.py", line 2123, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\engine\training.py", line 2111, in run_step
#       outputs = model.predict_step(data)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\engine\training.py", line 2079, in predict_step
#       return self(x, training=False)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\engine\training.py", line 561, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\engine\base_layer.py", line 1132, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\engine\sequential.py", line 413, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\engine\functional.py", line 511, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\engine\functional.py", line 668, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\engine\base_layer.py", line 1132, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\layers\convolutional\base_conv.py", line 314, in call
#       return self.activation(outputs)
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\activations.py", line 317, in relu
#       return backend.relu(
#     File "c:\Users\Alex\.conda\envs\tfm\lib\site-packages\keras\backend.py", line 5369, in relu
#       x = tf.nn.relu(x)
# Node: 'sequential/conv2d/Relu'
# convolution input must be 4-dimensional: [1,128,128]
# 	 [[{{node sequential/conv2d/Relu}}]] [Op:__inference_predict_function_10094]

# %% [markdown]
# Fixing the image for it to be a 3-dimensional data.

# %%
img  = Image.open(positive_file_paths[0]) 
print("The original image size is: ", img.size)
print("The image datatype is: ", type(img))
img = np.array(img.resize((128,128), Image.ANTIALIAS))
print("The image after resizing has size: ", img.shape)
print("The image type is also converted to: ", type(img))
img = np.dstack((img, img, img))
print("The image after resizing has size: ", img.shape)
print("The image type is also converted to: ", type(img))
# Out:
# The original image size is:  (1600, 1200)
# The image datatype is:  <class 'PIL.BmpImagePlugin.BmpImageFile'>
# The image after resizing has size:  (128, 128)
# The image type is also converted to:  <class 'numpy.ndarray'>
# The image after resizing has size:  (128, 128, 3)
# The image type is also converted to:  <class 'numpy.ndarray'>
# C:\Users\Alex\AppData\Local\Temp\ipykernel_16916\3706842763.py:4: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = np.array(img.resize((128,128), Image.ANTIALIAS))

# %%
plt.imshow(img)
plt.title("Converted to 3-channel image")
# Out:
# Text(0.5, 1.0, 'Converted to 3-channel image')

# %%
img = img / 255.
img = img[np.newaxis, :,:,:]
print("The image shape after an additional dimension is added, is: ", img.shape)
# Out:
# The image shape after an additional dimension is added, is:  (1, 128, 128, 3)

# %% [markdown]
# We can now perform the prediction because the image has the desired shape

# %%
reconstruction = model.predict([[img]])
# Out:
# 1/1 [==============================] - 0s 32ms/step

# %%
reconstruction_error = model.evaluate([reconstruction],[[img]], batch_size = 1)[0]
print("The reconstruction error of the chosen image is: ", reconstruction_error)
# Out:
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0073 - mse: 0.0073
# The reconstruction error of the chosen image is:  0.0072895134799182415

# %% [markdown]
# Finally, it is worth noting that when working with the positive images, the job of converting the image to 3-channel image is necessary. However, this is not necessary when working with the anomalies images; this might have something to do with the image file extension. See that the positive images have file extension ".bmp" whereas the anomalies images have ".jpg" file extension.

# %%
img2 = Image.open(anomaly_file_paths[0]) 
print("The original image size is: ", img2.size)
print("The image datatype is: ", type(img2))
img2 = np.array(img2.resize((128,128), Image.ANTIALIAS))
print("The image after resizing has size: ", img2.shape)
print("The image type is also converted to: ", type(img2))
# Out:
# The original image size is:  (1600, 1200)
# The image datatype is:  <class 'PIL.JpegImagePlugin.JpegImageFile'>
# The image after resizing has size:  (128, 128, 3)
# The image type is also converted to:  <class 'numpy.ndarray'>
# C:\Users\Alex\AppData\Local\Temp\ipykernel_16916\2794048470.py:4: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img2 = np.array(img2.resize((128,128), Image.ANTIALIAS))

# %% [markdown]
# See above, that the image already has 3-channels size: (128,128,3)

# %%
plt.imshow(img2)
plt.title("Resized image and converted into numpy array")
# Out:
# Text(0.5, 1.0, 'Resized image and converted into numpy array')

# %%
img2 = img2 / 255.
img2 = img2[np.newaxis, :,:,:]
print("The image shape after an additional dimension is added, is: ", img2.shape)
reconstruction_anomaly = model.predict([[img2]])
reconstruction_error_anomaly = model.evaluate([reconstruction_anomaly],[[img2]], batch_size = 1)[0]
print("The reconstruction error of the chosen image anomaly is: ", reconstruction_error_anomaly)
# Out:
# The image shape after an additional dimension is added, is:  (1, 128, 128, 3)
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0061 - mse: 0.0061
# The reconstruction error of the chosen image anomaly is:  0.006140314042568207

# %% [markdown]
# For this reason the "check_anomaly" function has an if clause that depending on the shape of the input image, it adds or not one more dimension to it.

# %%
img2 = Image.open(positive_file_paths[0]) 
img2 = np.array(img2.resize((128,128), Image.ANTIALIAS))
print("The image after resizing has size: ", img2.shape)
image_shape = img2.shape
print(len(image_shape))
# Out:
# The image after resizing has size:  (128, 128)
# 2
# C:\Users\Alex\AppData\Local\Temp\ipykernel_16916\4121947831.py:2: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img2 = np.array(img2.resize((128,128), Image.ANTIALIAS))

# %%
print("The image size is: ", img2.shape)
if(len(image_shape)==2):
    img2 = np.dstack((img2, img2, img2))
print("The image size is: ", img2.shape)
# Out:
# The image size is:  (128, 128)
# The image size is:  (128, 128, 3)

# %% [markdown]
# # Continuing with the usage of "check_anomaly" function

# %% [markdown]
# Checking the anomalies

# %%
num=random.randint(0,len(anomaly_file_paths)-1)
check_anomaly(anomaly_file_paths[num])
print("This image directory is: ", anomaly_file_paths[num])
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - ETA: 0s - loss: 0.0063 - mse: 0.0063
# C:\Users\Alex\AppData\Local\Temp\ipykernel_16916\3962754466.py:5: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = np.array(img.resize((128,128), Image.ANTIALIAS))
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0063 - mse: 0.0063
# The image IS an anomaly
# This image directory is:  C:\Users\Alex\Documents\BottleStoodUp_atNight\Anomalies\Anomalies_samples\img2.jpg

# %% [markdown]
# Checking the positive samples, these are NOT supposed to be anomalies.

# %%
num=random.randint(0,len(positive_file_paths)-1)
check_anomaly(positive_file_paths[num])
print("This image directory is: ", positive_file_paths[num])
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0057 - mse: 0.0057
# C:\Users\Alex\AppData\Local\Temp\ipykernel_16916\3962754466.py:5: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = np.array(img.resize((128,128), Image.ANTIALIAS))
# The image is NOT an anomaly
# This image directory is:  C:\Users\Alex\Documents\BottleStoodUp_atNight\Positive\Positive_samples\07-03-2023 - 22.28.40_8.bmp

# %% [markdown]
# From the specific tests above, the model has succesfully discriminated negative samples from the positive ones. However, an overall performance check is poor. See the obtained results below:

# %% [markdown]
# # Working on the latent space of the model

# %% [markdown]
# This is a different approach of setting a threshold and detecting an anomaly. Instead of working directly with the error metric at the end of the model, it will be reached until the latent space of the model and in here a threshold value will be selected.

# %% [markdown]
# Let us extract (or build) the encoder network, with trained weights.
#
# This is used to get the compressed output (latent space) of the input image.
#
# The compressed output is then used to calculate the KDE

# %%
encoder_model = Sequential()
encoder_model.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(SIZE, SIZE, 3), weights=model.layers[0].get_weights()) )
encoder_model.add(MaxPooling2D((2, 2), padding='same'))
encoder_model.add(Conv2D(32, (3, 3), activation='relu', padding='same', weights=model.layers[2].get_weights()))
encoder_model.add(MaxPooling2D((2, 2), padding='same'))
encoder_model.add(Conv2D(16, (3, 3), activation='relu', padding='same', weights=model.layers[4].get_weights()))
encoder_model.add(MaxPooling2D((2, 2), padding='same'))
encoder_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 128, 128, 64)      1792
#
#  max_pooling2d_3 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 32)        18464
#
#  max_pooling2d_4 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 16)        4624
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
# =================================================================
# Total params: 24,880
# Trainable params: 24,880
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# NOtice that the new model: "encoder_model" is the same as "model" but without considering the decoder part of it, only the encoder part.

# %% [markdown]
# It is now time to use this new model. This will generate a feature vector or also called by the video source of this notebook, the latent vector.

# %%
########################################################
# Calculate KDE using sklearn
from sklearn.neighbors import KernelDensity

#Get encoded output of input images = Latent space
encoded_images = encoder_model.predict_generator(train_generator)
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_8136\454703430.py:6: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   encoded_images = encoder_model.predict_generator(train_generator)

# %%
print(encoded_images.shape)
# Out:
# (13704, 16, 16, 16)

# %% [markdown]
# See that it is 13704 length because it corresponds to all the images that belong to the training dataset. Also the shape of the representation of the original images has been lowered to (16, 16, 16) as specified in the model structure.

# %%
type(encoded_images)
# Out:
# numpy.ndarray

# %% [markdown]
# Now we will flatten the encoder output because KDE from sklearn takes 1D vectors as input

# %% [markdown]
# First we print the output shape of the encoder model

# %%
encoder_output_shape = encoder_model.output_shape #Here, we have 16x16x16
print(encoder_output_shape)
# Out:
# (None, 16, 16, 16)

# %% [markdown]
# Then we flatten the output of the enconded images in order for it to be (13704, 16 * 16 * 16)

# %%
out_vector_shape = encoder_output_shape[1]*encoder_output_shape[2]*encoder_output_shape[3]
encoded_images_vector = [np.reshape(img, (out_vector_shape)) for img in encoded_images]

# %%
len(encoded_images_vector)
# Out:
# 13704

# %%
encoded_images_vector[0].shape
# Out:
# (4096,)

# %% [markdown]
# Now, let's fit KDE to the image latent data

# %%
kde = KernelDensity(kernel='gaussian', bandwidth=0.2).fit(encoded_images_vector)

# %% [markdown]
# The above function fits a kernel density estimation to the data that is provided, that is, the "encoded_images_vector" variable. It does so using a Guassian kernel of bandwidth 0.2.
#
# The badnwidth parameter affects on how the selected kernel will fit each sample of the given data. For example for the case in which the kernel is a Gaussian distribution, the bandwidth parameter would affect in how thin or wide is the Gaussian distribution.

# %% [markdown]
# At this point in the variable "kde" we have some numbers that are the result of fitting Gaussian functions to the given data points in the variable "encoded_images_vecotr". We will use the "kde" variable later for scoring with it, some given data points; the scoring will be given depending on how similar are the given data points to the ones that it had estimated.

# %%
#Calculate density and reconstruction error to find their means values for
#good and anomaly images. 
#We use these mean and sigma to set thresholds. 
def calc_density_and_recon_error(batch_images):
    
    density_list=[]
    recon_error_list=[]
    for im in range(0, batch_images.shape[0]-1):
        
        img  = batch_images[im]
        img = img[np.newaxis, :,:,:]
        encoded_img = encoder_model.predict([[img]]) # Create a compressed version of the image using the encoder
        encoded_img = [np.reshape(img, (out_vector_shape)) for img in encoded_img] # Flatten the compressed image
        density = kde.score_samples(encoded_img)[0] # get a density score for the new image
        reconstruction = model.predict([[img]])
        reconstruction_error = model.evaluate([reconstruction],[[img]], batch_size = 1)[0]
        density_list.append(density)
        recon_error_list.append(reconstruction_error)
    average_density = np.mean(np.array(density_list))  
    stdev_density = np.std(np.array(density_list)) 
    
    average_recon_error = np.mean(np.array(recon_error_list))  
    stdev_recon_error = np.std(np.array(recon_error_list)) 
    
    return average_density, stdev_density, average_recon_error, stdev_recon_error

# %% [markdown]
# The function above, given a batch of images, does:
# - Encodes a single image.
# - Flattens the encoded image.
# - Assign a density score of the flattened image using the previously computed "kde" variable.
# - Computes a reconstruction error of the image. For this it uses the complete neural network model, the one that was created at the beginning.
# - Appends in two lists:
#     - The reconstruction error.
#     - The density score of the encoded model result.
# - At the end, based on the density and reconstruction error, the funtion otuputs the mean and standard deviation of both metrics.

# %%
#Get average and std dev. of density and recon. error for uninfected and anomaly (parasited) images. 
#For this let us generate a batch of images for each. 
train_batch = train_generator.next()[0]     # This is the uninfected images
anomaly_batch = anomaly_generator.next()[0] # This is the parasitized images

uninfected_values = calc_density_and_recon_error(train_batch)
anomaly_values = calc_density_and_recon_error(anomaly_batch)
# Out:
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 145ms/step - loss: 0.0045 - mse: 0.0045
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0051 - mse: 0.0051
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0055 - mse: 0.0055
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0050 - mse: 0.0050
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0060 - mse: 0.0060
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0056 - mse: 0.0056
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0054 - mse: 0.0054
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0060 - mse: 0.0060
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0052 - mse: 0.0052
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0067 - mse: 0.0067
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0048 - mse: 0.0048
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0077 - mse: 0.0077
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0051 - mse: 0.0051
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0067 - mse: 0.0067
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0046 - mse: 0.0046
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0050 - mse: 0.0050
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0044 - mse: 0.0044
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0044 - mse: 0.0044
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0050 - mse: 0.0050
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0046 - mse: 0.0046
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0044 - mse: 0.0044
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0052 - mse: 0.0052
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0042 - mse: 0.0042
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0057 - mse: 0.0057
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0053 - mse: 0.0053
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0061 - mse: 0.0061
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0050 - mse: 0.0050
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0049 - mse: 0.0049
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0050 - mse: 0.0050
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0053 - mse: 0.0053
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0079 - mse: 0.0079
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0073 - mse: 0.0073
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0064 - mse: 0.0064
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0055 - mse: 0.0055
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0063 - mse: 0.0063
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0076 - mse: 0.0076
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0051 - mse: 0.0051
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0074 - mse: 0.0074
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0054 - mse: 0.0054
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0061 - mse: 0.0061
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0055 - mse: 0.0055
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0066 - mse: 0.0066
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0046 - mse: 0.0046
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0053 - mse: 0.0053
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0053 - mse: 0.0053
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0059 - mse: 0.0059
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0044 - mse: 0.0044
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0048 - mse: 0.0048
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0035 - mse: 0.0035
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0059 - mse: 0.0059
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0048 - mse: 0.0048
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0049 - mse: 0.0049
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0050 - mse: 0.0050
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0047 - mse: 0.0047
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0057 - mse: 0.0057
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0060 - mse: 0.0060
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0053 - mse: 0.0053
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0056 - mse: 0.0056
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0070 - mse: 0.0070
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0042 - mse: 0.0042
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0072 - mse: 0.0072
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0062 - mse: 0.0062
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0061 - mse: 0.0061
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0109 - mse: 0.0109
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0084 - mse: 0.0084
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0063 - mse: 0.0063
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0064 - mse: 0.0064
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0058 - mse: 0.0058
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0056 - mse: 0.0056
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0071 - mse: 0.0071
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0093 - mse: 0.0093
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0064 - mse: 0.0064
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0083 - mse: 0.0083
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0056 - mse: 0.0056
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0050 - mse: 0.0050
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0057 - mse: 0.0057
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0066 - mse: 0.0066
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0098 - mse: 0.0098
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0065 - mse: 0.0065
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0057 - mse: 0.0057
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0115 - mse: 0.0115
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0060 - mse: 0.0060
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0085 - mse: 0.0085
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0065 - mse: 0.0065
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0073 - mse: 0.0073
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0051 - mse: 0.0051
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0066 - mse: 0.0066
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0067 - mse: 0.0067
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0056 - mse: 0.0056
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0079 - mse: 0.0079
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0073 - mse: 0.0073
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0081 - mse: 0.0081
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0089 - mse: 0.0089
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0066 - mse: 0.0066
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0056 - mse: 0.0056
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0045 - mse: 0.0045
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0077 - mse: 0.0077
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0066 - mse: 0.0066
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0092 - mse: 0.0092
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0056 - mse: 0.0056
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0071 - mse: 0.0071
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0069 - mse: 0.0069
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0064 - mse: 0.0064
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0057 - mse: 0.0057
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0079 - mse: 0.0079
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0064 - mse: 0.0064
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0057 - mse: 0.0057
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0056 - mse: 0.0056
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0064 - mse: 0.0064
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0051 - mse: 0.0051
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0077 - mse: 0.0077
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0077 - mse: 0.0077
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0065 - mse: 0.0065
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0059 - mse: 0.0059
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0066 - mse: 0.0066
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0075 - mse: 0.0075
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0060 - mse: 0.0060
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0070 - mse: 0.0070
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0059 - mse: 0.0059
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0073 - mse: 0.0073
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0062 - mse: 0.0062
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0058 - mse: 0.0058

# %% [markdown]
# See that "uninfected_values" and "anomaly_values" have length of four and contain the average_density, stdev_density, average_recon_error, stdev_recon_error

# %%
print(uninfected_values)
print(anomaly_values)
# Out:
# (2818.7600142837364, 7.087883489561854e-12, 0.005494946303466956, 0.0009135791106844122)
# (1635.4463236000852, 1167.4125009720128, 0.0068234895755137715, 0.0013553442590894956)

# %%
#Now, input unknown images and sort as Good or Anomaly
def check_anomaly(img_path):
    density_threshold = 2500 #Set this value based on the above exercise
    reconstruction_error_threshold = 0.006 # Set this value based on the above exercise
    img  = Image.open(img_path)
    img = np.array(img.resize((128,128), Image.ANTIALIAS))
    plt.imshow(img)
    img = img / 255.
    img = img[np.newaxis, :,:,:]
    encoded_img = encoder_model.predict([[img]]) 
    encoded_img = [np.reshape(img, (out_vector_shape)) for img in encoded_img] 
    density = kde.score_samples(encoded_img)[0] 

    reconstruction = model.predict([[img]])
    reconstruction_error = model.evaluate([reconstruction],[[img]], batch_size = 1)[0]

    if density < density_threshold or reconstruction_error > reconstruction_error_threshold:
        print("The image is an anomaly")
        
    else:
        print("The image is NOT an anomaly")

# %%
#Load a couple of test images and verify whether they are reported as anomalies.
import glob
para_file_paths = glob.glob(r'C:\Users\Alex\Documents\TFM_project\cellsDataset\cell_images\parasitized1\Parasitized\*')
uninfected_file_paths = glob.glob(r'C:\Users\Alex\Documents\TFM_project\cellsDataset\cell_images\uninfected1\Uninfected\*')

# %%
#Anomaly image verification
num=random.randint(0,len(para_file_paths)-1)
check_anomaly(para_file_paths[num])
# Out:
# 1/1 [==============================] - 0s 30ms/step
# C:\Users\Alex\AppData\Local\Temp\ipykernel_8136\349380335.py:6: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = np.array(img.resize((128,128), Image.ANTIALIAS))
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0056 - mse: 0.0056
# The image is an anomaly

# %%
#Good/normal image verification
num=random.randint(0,len(uninfected_file_paths)-1)
check_anomaly(uninfected_file_paths[num])
# Out:
# 1/1 [==============================] - 0s 32ms/step
# C:\Users\Alex\AppData\Local\Temp\ipykernel_8136\3669532084.py:6: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = np.array(img.resize((128,128), Image.ANTIALIAS))
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0059 - mse: 0.0059
# The image is NOT an anomaly
