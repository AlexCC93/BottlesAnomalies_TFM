# %%
# Importing libraries

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras
import tensorflow as tf
# from keras import layers


from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.preprocessing import image

import tensorflow.keras.backend as K


from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) == 0:
    print("Not enough GPU hardware devices available")
else:
    config = tf.config.experimental.set_memory_growth(physical_devices[0], True)
print("Num GPUs Available: ", len(physical_devices))
# Out:
# Num GPUs Available:  1
# 2023-08-19 23:05:15.491797: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-08-19 23:05:15.514574: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-19 23:05:15.514856: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2080 with Max-Q Design computeCapability: 7.5
# coreClock: 1.23GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 357.69GiB/s
# 2023-08-19 23:05:15.515026: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2023-08-19 23:05:15.516283: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2023-08-19 23:05:15.517624: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2023-08-19 23:05:15.517838: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2023-08-19 23:05:15.519151: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2023-08-19 23:05:15.519876: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2023-08-19 23:05:15.522607: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-08-19 23:05:15.522697: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-19 23:05:15.523017: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-19 23:05:15.523263: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0

# %% [markdown]
# If uncommented it will print all the log information about where the tensorflow operations were performed, in the CPU or the GPU

# %%
# tf.debugging.set_log_device_placement(True)       # Will print the log information of every execution of tensorflow, mainly about

# %% [markdown]
# # Loading the train data set

# %% [markdown]
# ImageDataGenerator.flow_from_directory: Takes the path to a directory and generates batches of augmented data.

# %%
def my_crop(img, start_y, start_x, desired_height, desired_width):
  if K.image_data_format() == 'channels_last':
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    dy = desired_height #input desired output size
    dx = desired_width #input desired output size
    # start_y = (height-dy)//2
    # start_x = (width-dx)//2
    return img[start_y:start_y+dy, start_x:(dx+start_x), :]
  else:
      assert img.shape[0] == 3
      dy = desired_height #input desired output size
      dx = desired_width #input desired output size
      # start_y = (height-dy)//2
      # start_x = (width-dx)//2
      return img[:,start_y:start_y + dy, start_x:(dx + start_x)]

def crop_augmented_generator(batches, start_y, start_x, crop_height, crop_width):
    '''
    Take as input a Keras ImageGen (Iterator) and generate
    crops from the image batches generated by the original iterator
    '''
    # print("I'm in the crop_generataor function")
    while True:
      batch_x, batch_y = next(batches)  # In batch_x there are the images, in batch_y there are the labels
    #   print("hello")
    #   print('the shape of tensor batch_x is:', batch_x.shape)
    #   print('batch_y is:', batch_y)
    
      if K.image_data_format() == 'channels_last':
        # print("type of batch_x: ", type(batch_x))
        # print("type of batch_y: ", type(batch_y))
        # print("len of batch_x: ", len(batch_x))

        # Either batch_x or batch_y could be augmented or original
        batch_crops_input_x = np.zeros((batch_x[0].shape[0], crop_height, crop_width, 3))
        batch_crops_target_x = np.zeros((batch_x[1].shape[0], crop_height, crop_width, 3))

        batch_crops_input_y = np.zeros((batch_y[0].shape[0], crop_height, crop_width, 3))
        batch_crops_target_y = np.zeros((batch_y[1].shape[0], crop_height, crop_width, 3))
      else:
        # Either batch_x or batch_y could be augmented or original
        batch_crops_input_x = np.zeros((batch_x[0].shape[0], 3, crop_height, crop_width))
        batch_crops_target_x = np.zeros((batch_x[1].shape[0], 3, crop_height, crop_width))

        batch_crops_input_y = np.zeros((batch_y[0].shape[0], 3, crop_height, crop_width))
        batch_crops_target_y = np.zeros((batch_y[1].shape[0], 3, crop_height, crop_width))

      for i in range(batch_x[0].shape[0]):
        #   print("THe shape of a single image before the cropping is: ", batch_x[i].shape)
        batch_crops_input_x[i] = my_crop(batch_x[0][i], start_y, start_x, crop_height, crop_width)
        batch_crops_target_x[i] = my_crop(batch_x[1][i], start_y, start_x, crop_height, crop_width)

        batch_crops_input_y[i] = my_crop(batch_y[0][i], start_y, start_x, crop_height, crop_width)
        batch_crops_target_y[i] = my_crop(batch_y[1][i], start_y, start_x, crop_height, crop_width)
      
      # print(type(batch_crops_input_x))
      batch_crops_x = (batch_crops_input_x, batch_crops_target_x)
      batch_crops_y = (batch_crops_input_y, batch_crops_target_y)

      yield (batch_crops_x, batch_crops_y)

  
    
def crop_generator(batches, start_y, start_x, crop_height, crop_width, flag=0):
    '''
    Take as input a Keras ImageGen (Iterator) and generate
    crops from the image batches generated by the original iterator
    '''
    # print("I'm in the crop_generataor function")
    while True:
      batch_x, batch_y = next(batches)  # In batch_x there are the images, in batch_y there are the labels
    #   print("hello")
    #   print('the shape of tensor batch_x is:', batch_x.shape)
    #   print('batch_y is:', batch_y)
      if flag==0:
        if K.image_data_format() == 'channels_last':
          batch_crops = np.zeros((batch_x.shape[0], crop_height, crop_width, 3))
          batch_crops_y = np.zeros((batch_y.shape[0], crop_height, crop_width, 3))
        else:
          batch_crops = np.zeros((batch_x.shape[0], 3, crop_height, crop_width))
          batch_crops_y = np.zeros((batch_y.shape[0], 3, crop_height, crop_width))
        for i in range(batch_x.shape[0]):
          #   print("THe shape of a single image before the cropping is: ", batch_x[i].shape)
            batch_crops[i] = my_crop(batch_x[i], start_y, start_x, crop_height, crop_width)
            batch_crops_y[i] = my_crop(batch_x[i], start_y, start_x, crop_height, crop_width)
        yield (batch_crops, batch_crops_y)
      else: 
        if K.image_data_format() == 'channels_last':
          batch_crops = np.zeros((batch_x.shape[0], crop_height, crop_width, 3))
        else:
          batch_crops = np.zeros((batch_x.shape[0], 3, crop_height, crop_width))
        for i in range(batch_x.shape[0]):
          #   print("THe shape of a single image before the cropping is: ", batch_x[i].shape)
            batch_crops[i] = my_crop(batch_x[i], start_y, start_x, crop_height, crop_width)

        yield (batch_crops, batch_y)

# %%
# batch_size = 64
batch_size = 10
train_datagen = ImageDataGenerator(rescale=1./255,
                                    brightness_range=[0.88,1.0]) # Typically used for data augmentation. Here it is only rescaling the image pixels value to range 0 to 1 in decimals and changing the brightness


original_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    "../../Images/june5Night/Positive/",         # For home laptop
    # "../../../BottleStoodUp_atNight/Positive/",          # For work laptop
    batch_size=batch_size,
    shuffle = False,
    class_mode='input'
    )

# Generate original images from the original data directory
original_generator = original_datagen.flow_from_directory(
    "../../Images/june5Night/Positive/",
    batch_size=batch_size,
    shuffle = False,
    class_mode='input')

# Combine the generators using the `keras.preprocessing.image.Iterator` class
combined_generator = zip(train_generator, original_generator)
# Out:
# Found 295 images belonging to 1 classes.
# Found 295 images belonging to 1 classes.

# %%
validation_generator = original_datagen.flow_from_directory(
    "../../Images/june5Night/Positive_val/",     # For home laptop
    # "../../../BottleStoodUp_atNight/Positive_val/",           # For work lpatop   
    batch_size=batch_size,
    shuffle = False,
    class_mode='input'
    )
# Out:
# Found 20 images belonging to 1 classes.

# %%
validation_generator_for_threshold = original_datagen.flow_from_directory(
    "../../Images/june5Night/Validation/",     # For home laptop
    # "../../../BottleStoodUp_atNight/Positive_val/",           # For work lpatop   
    batch_size=batch_size,
    shuffle = False,
    class_mode='binary'
    )
# Out:
# Found 30 images belonging to 2 classes.

# %%
anomaly_generator = original_datagen.flow_from_directory(
    "../../Images/june5Night/Anomalies2.0/",         # For home laptop
    # "../../../BottleStoodUp_atNight/Anomalies2.0/",           # For work lpatpo
    batch_size=batch_size,
    shuffle = False,
    class_mode='input'
    )
# Out:
# Found 10 images belonging to 1 classes.

# %%
test_set_generator = original_datagen.flow_from_directory(
    "../../Images/june5Night/Evaluation/",       # For home laptop
    # "../../../BottleStoodUp_atNight/Evaluation/",             # For work laptop  
    batch_size=batch_size,
    shuffle = False,
    class_mode='binary'
    )
# Out:
# Found 30 images belonging to 2 classes.

# %% [markdown]
# # Showing one sample of the training set images

# %% [markdown]
# Creating the cropped images

# %%
HEIGHT = 160
WIDTH = 128

# %%
train_crops = crop_augmented_generator(combined_generator, 65, 69, HEIGHT,WIDTH)      # top, left, height, width
val_crops = crop_generator(validation_generator, 65, 69, HEIGHT,WIDTH)      # top, left, height, width
anomaly_crops = crop_generator(anomaly_generator, 65, 69, HEIGHT,WIDTH)      # top, left, height, width
test_crops = crop_generator(test_set_generator, 65, 69, HEIGHT,WIDTH,1)      # top, left, height, width
val_crops_for_threshold = crop_generator(validation_generator_for_threshold, 65, 69, HEIGHT,WIDTH,1)      # top, left, height, width

# %% [markdown]
# Here we make sure that both of the returned elements of the cropped generator, that is "imgaes_in_batch" and "imgaes_in_batch2", are indeed cropped images.

# %%
images_in_batch, images_in_batch2 = next(train_crops)

# %%
batch_input_images1 = images_in_batch[0]
batch_expected_images1 = images_in_batch[1]
print(batch_input_images1.shape)
print(batch_expected_images1.shape)
# Out:
# (10, 160, 128, 3)
# (10, 160, 128, 3)

# %%
batch_input_images2 = images_in_batch2[0]
batch_expected_images2 = images_in_batch2[1]
print(batch_input_images2.shape)
print(batch_expected_images2.shape)
# Out:
# (10, 160, 128, 3)
# (10, 160, 128, 3)

# %%
single_img_batch1 = batch_input_images1[0]
plt.imshow(single_img_batch1)

# %%
single_img_batch2 = batch_input_images2[0]
plt.imshow(single_img_batch2)

# %% [markdown]
# # Building the model Autoencoder model

# %%
latent_dim = 40  # Number of latent dimension parameters

input_img = Input(shape=(HEIGHT, WIDTH, 3))
x = Conv2D(64, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = MaxPool2D( (2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = MaxPool2D( (2, 2), padding='same')(x)

x = Conv2D(4, (3, 3), activation='relu', padding='same')(x)
x = MaxPool2D( (2, 2), padding='same')(x)
x = Conv2D(1, (3, 3), activation='relu', padding='same')(x)

shape_before_flattening = K.int_shape(x)
print(shape_before_flattening)
x = Flatten()(x)
x = Dense(80, activation='relu')(x)        # Activation function is supposed to be none, i.e the output is the same as the input

Z = Dense(latent_dim)(x)
print(K.int_shape(Z))

encoder = Model(input_img,Z)
encoder.summary()
# Out:
# 2023-08-19 23:05:16.092035: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2023-08-19 23:05:16.117597: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2599990000 Hz
# 2023-08-19 23:05:16.118189: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f578c0012d0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-08-19 23:05:16.118221: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-08-19 23:05:16.187833: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-19 23:05:16.188183: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x60ccd50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-08-19 23:05:16.188198: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 with Max-Q Design, Compute Capability 7.5
# 2023-08-19 23:05:16.188334: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-19 23:05:16.188615: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2080 with Max-Q Design computeCapability: 7.5
# coreClock: 1.23GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 357.69GiB/s
# 2023-08-19 23:05:16.188651: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2023-08-19 23:05:16.188664: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2023-08-19 23:05:16.188676: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2023-08-19 23:05:16.188712: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2023-08-19 23:05:16.188725: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2023-08-19 23:05:16.188738: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2023-08-19 23:05:16.188750: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-08-19 23:05:16.188797: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-19 23:05:16.189095: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-19 23:05:16.189336: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2023-08-19 23:05:16.189367: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2023-08-19 23:05:16.189758: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-08-19 23:05:16.189767: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2023-08-19 23:05:16.189773: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2023-08-19 23:05:16.189851: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-19 23:05:16.190126: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-19 23:05:16.190364: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 3961 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5)
# (None, 10, 8, 1)
# (None, 40)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 160, 128, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 160, 128, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 80, 64, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 80, 64, 32)        18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 40, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 40, 32, 16)        4624
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 20, 16, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 16, 4)         580
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 8, 4)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 8, 1)          37
# _________________________________________________________________
# flatten (Flatten)            (None, 80)                0
# _________________________________________________________________
# dense (Dense)                (None, 80)                6480
# _________________________________________________________________
# dense_1 (Dense)              (None, 40)                3240
# =================================================================
# Total params: 35,217
# Trainable params: 35,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
# decoder takes the latent distribution sample as input
decoder_input = Input(K.int_shape(Z)[1:])
x = Dense(10*8*4, activation='relu', name="intermediate_decoder", input_shape=(latent_dim,))(decoder_input)
# Expand to 784 total pixels
x = Dense(320, activation='sigmoid', name="original_decoder")(x)
x = Reshape((10,8,4),input_shape=(320,))(x)

x = Conv2DTranspose(3, (3, 3), padding='same')(x)
x = UpSampling2D( (2, 2))(x)
x = Conv2DTranspose(3, (3, 3), padding='same')(x)
x = UpSampling2D( (2, 2))(x)
x = Conv2DTranspose(3, (3, 3), padding='same')(x)
x = UpSampling2D( (2, 2))(x)
x = Conv2DTranspose(3, (3, 3), padding='same')(x)
x = UpSampling2D( (2, 2))(x)

# decoder model statement
decoder = Model(decoder_input, x)

# apply the decoder to the sample from the latent distribution
z_decoded = decoder(Z)

decoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 40)]              0
# _________________________________________________________________
# intermediate_decoder (Dense) (None, 320)               13120
# _________________________________________________________________
# original_decoder (Dense)     (None, 320)               102720
# _________________________________________________________________
# reshape (Reshape)            (None, 10, 8, 4)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 10, 8, 3)          111
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 20, 16, 3)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 20, 16, 3)         84
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 40, 32, 3)         0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 40, 32, 3)         84
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 80, 64, 3)         0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 80, 64, 3)         84
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 160, 128, 3)       0
# =================================================================
# Total params: 116,203
# Trainable params: 116,203
# Non-trainable params: 0
# _________________________________________________________________

# %%
# VAE model statement
ae = Model(input_img,z_decoded)
ae.compile(optimizer='adam', loss='mean_squared_error')

ae.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 160, 128, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 160, 128, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 80, 64, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 80, 64, 32)        18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 40, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 40, 32, 16)        4624
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 20, 16, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 16, 4)         580
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 8, 4)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 8, 1)          37
# _________________________________________________________________
# flatten (Flatten)            (None, 80)                0
# _________________________________________________________________
# dense (Dense)                (None, 80)                6480
# _________________________________________________________________
# dense_1 (Dense)              (None, 40)                3240
# _________________________________________________________________
# model_1 (Model)              (None, 160, 128, 3)       116203
# =================================================================
# Total params: 151,420
# Trainable params: 151,420
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Training the model

# %%
# # from tensorflow.keras.callbacks import EarlyStopping
# # run the modelvalidat
# # early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=5, mode='auto')
# history = ae.fit(train_crops, epochs=300, steps_per_epoch=len(train_generator)*2, validation_data=val_crops, validation_steps =len(validation_generator),  verbose=1, shuffle = True)

# %%
# # Get the training and validation loss values from the history object
# train_loss = history.history['loss']
# val_loss = history.history['val_loss']

# # Plot the training and validation loss
# epochs = range(1, len(train_loss) + 1)
# plt.plot(epochs, train_loss, 'b-', label='Training Loss')
# plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
# plt.title('Training and Validation Loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %% [markdown]
# Saving the train and validation history data

# %%
# # open file
# with open('txtFilesAutoencoderBottles6/TrainingLoss.txt', 'w+') as g:
#     # write elements of list
#     for items in train_loss:
#         g.write('%s\n' %items)
#     print("train_loss written successfully")
# # close the file
# g.close() 

# # open file
# with open('txtFilesAutoencoderBottles6/ValidationLoss.txt', 'w+') as g:
#     # write elements of list
#     for items in val_loss:
#         g.write('%s\n' %items)
#     print("val_loss written successfully")
# # close the file
# g.close()

# %% [markdown]
# LOading the train and validation history data

# %%
# Load data from the text file
with open("txtFilesAutoencoderBottles6/TrainingLoss.txt", "r") as file:
    train_loss_data = [float(line.strip()) for line in file]

# Load data from the text file
with open("txtFilesAutoencoderBottles6/ValidationLoss.txt", "r") as file:
    val_loss_data = [float(line.strip()) for line in file]

# Plot the training and validation loss
epochs = range(1, len(train_loss_data) + 1)
plt.plot(epochs, train_loss_data, 'b-', label='Training Loss')
plt.plot(epochs, val_loss_data, 'r-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
filepath = "models/Bottles6_playground"

# %%
# ae.save(f"{filepath}")

# %% [markdown]
# Loading the model that was previously saved

# %%
# VAE model statement
model = Model(input_img,z_decoded)
model.compile(optimizer='adam', loss='mean_squared_error')

model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 160, 128, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 160, 128, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 80, 64, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 80, 64, 32)        18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 40, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 40, 32, 16)        4624
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 20, 16, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 16, 4)         580
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 8, 4)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 8, 1)          37
# _________________________________________________________________
# flatten (Flatten)            (None, 80)                0
# _________________________________________________________________
# dense (Dense)                (None, 80)                6480
# _________________________________________________________________
# dense_1 (Dense)              (None, 40)                3240
# _________________________________________________________________
# model_1 (Model)              (None, 160, 128, 3)       116203
# =================================================================
# Total params: 151,420
# Trainable params: 151,420
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = keras.models.load_model(f'{filepath}')
print(type(model))
# Out:
# <class 'tensorflow.python.keras.engine.training.Model'>

# %% [markdown]
# # Quantifying the reconstruction error using "evaluate_generator()" function

# %% [markdown]
# Performing the computation of the reconstruction error of all the images in the training dataset. Computing the MSE of each image with its reconstructed version.

# %%
training_error = model.evaluate_generator(train_crops, steps=len(train_generator)*2)
print("Recon. error for the training (non-anomaly) data is: ", training_error)
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_106072/1524259704.py:1: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# 2023-08-19 23:05:18.548815: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2023-08-19 23:05:18.743686: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# Recon. error for the training (non-anomaly) data is:  0.004599067382514477

# %% [markdown]
# # Computing the reconstruction error without using the "evaluate_generator()" function

# %% [markdown]
# The following function computes the reconstrution error per each batch of images. It does, for each of the batches:
# - Initialize a vector for storing the reconstruction errors.
# - A for loop that traverses all the images contained in a batch.
#     - Take the one image of the batch.
#     - Add a new size dimension to the image.
#     - Make a prediction of the selected image with the model that was built.
#     - Evaluate the performance of the prediction, i.e. compute the prediction error.
#     - Append the reconstruction error into a list.
# - Compute the mean and std deviation of the error.

# %%
def calc_recon_error(batch_images):   
    recon_error_list=[]
    for im in range(0, batch_images.shape[0]):
        img  = batch_images[im]
        img = img[np.newaxis, :,:,:]
        reconstruction = model.predict([[img]])
        # reconstruction_error = model.evaluate([reconstruction],[[img]], batch_size = 1)[0]    # The batch_size parameter for the moment can be supressed. Results were seen to be the same
        # reconstruction_error = model.evaluate([reconstruction],[[img]])[0]                    # It included the [0] subscription but with this new model, the rec error is directly a float value, so no more need for subscription
        reconstruction_error = model.evaluate([reconstruction],[[img]])
        recon_error_list.append(reconstruction_error)   
    return recon_error_list

# %%
total_rec_error = []
for i in range(len(train_generator)):                               #This will traverse the train generator the number of batches it contains
    images_in_batch, images_in_batch2 = next(train_crops)           #As for each next step of the "train_crops" generator it exists one batch of the augmented and one batch of the orignial images, we perform twice the calc_recon_error() function
    batch_input_images1 = images_in_batch[0]
    total_rec_error.append(calc_recon_error(batch_input_images1))
    batch_input_images2 = images_in_batch2[0]
    total_rec_error.append(calc_recon_error(batch_input_images2))
    
print("The list of rec. error contains ", len(total_rec_error), "batches of rec. errors")
# Out:
# 1/1 [==============================] - 0s 734us/step - loss: 0.0060
# 1/1 [==============================] - 0s 622us/step - loss: 0.0061
# 1/1 [==============================] - 0s 632us/step - loss: 0.0066
# 1/1 [==============================] - 0s 607us/step - loss: 0.0059
# 1/1 [==============================] - 0s 627us/step - loss: 0.0063
# 1/1 [==============================] - 0s 614us/step - loss: 0.0077
# 1/1 [==============================] - 0s 713us/step - loss: 0.0064
# 1/1 [==============================] - 0s 594us/step - loss: 0.0057
# 1/1 [==============================] - 0s 624us/step - loss: 0.0054
# 1/1 [==============================] - 0s 729us/step - loss: 0.0056
# 1/1 [==============================] - 0s 921us/step - loss: 0.0055
# 1/1 [==============================] - 0s 783us/step - loss: 0.0056
# 1/1 [==============================] - 0s 894us/step - loss: 0.0056
# 1/1 [==============================] - 0s 964us/step - loss: 0.0056
# 1/1 [==============================] - 0s 672us/step - loss: 0.0052
# 1/1 [==============================] - 0s 645us/step - loss: 0.0051
# 1/1 [==============================] - 0s 740us/step - loss: 0.0049
# 1/1 [==============================] - 0s 777us/step - loss: 0.0050
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0055
# 1/1 [==============================] - 0s 981us/step - loss: 0.0056
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0075
# 1/1 [==============================] - 0s 757us/step - loss: 0.0056
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0053
# 1/1 [==============================] - 0s 711us/step - loss: 0.0055
# 1/1 [==============================] - 0s 648us/step - loss: 0.0123
# 1/1 [==============================] - 0s 883us/step - loss: 0.0135
# 1/1 [==============================] - 0s 881us/step - loss: 0.0118
# 1/1 [==============================] - 0s 620us/step - loss: 0.0070
# 1/1 [==============================] - 0s 609us/step - loss: 0.0056
# 1/1 [==============================] - 0s 622us/step - loss: 0.0060
# 1/1 [==============================] - 0s 605us/step - loss: 0.0056
# 1/1 [==============================] - 0s 603us/step - loss: 0.0056
# 1/1 [==============================] - 0s 790us/step - loss: 0.0049
# 1/1 [==============================] - 0s 781us/step - loss: 0.0052
# 1/1 [==============================] - 0s 716us/step - loss: 0.0073
# 1/1 [==============================] - 0s 843us/step - loss: 0.0073
# 1/1 [==============================] - 0s 631us/step - loss: 0.0075
# 1/1 [==============================] - 0s 738us/step - loss: 0.0051
# 1/1 [==============================] - 0s 676us/step - loss: 0.0049
# 1/1 [==============================] - 0s 692us/step - loss: 0.0052
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0052
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0059
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0073
# 1/1 [==============================] - 0s 901us/step - loss: 0.0064
# 1/1 [==============================] - 0s 799us/step - loss: 0.0114
# 1/1 [==============================] - 0s 781us/step - loss: 0.0128
# 1/1 [==============================] - 0s 839us/step - loss: 0.0074
# 1/1 [==============================] - 0s 915us/step - loss: 0.0112
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0134
# 1/1 [==============================] - 0s 824us/step - loss: 0.0065
# 1/1 [==============================] - 0s 854us/step - loss: 0.0055
# 1/1 [==============================] - 0s 930us/step - loss: 0.0053
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0058
# 1/1 [==============================] - 0s 865us/step - loss: 0.0061
# 1/1 [==============================] - 0s 731us/step - loss: 0.0063
# 1/1 [==============================] - 0s 623us/step - loss: 0.0069
# 1/1 [==============================] - 0s 653us/step - loss: 0.0069
# 1/1 [==============================] - 0s 783us/step - loss: 0.0073
# 1/1 [==============================] - 0s 895us/step - loss: 0.0073
# 1/1 [==============================] - 0s 675us/step - loss: 0.0052
# 1/1 [==============================] - 0s 597us/step - loss: 0.0064
# 1/1 [==============================] - 0s 637us/step - loss: 0.0063
# 1/1 [==============================] - 0s 621us/step - loss: 0.0072
# 1/1 [==============================] - 0s 612us/step - loss: 0.0070
# 1/1 [==============================] - 0s 904us/step - loss: 0.0062
# 1/1 [==============================] - 0s 751us/step - loss: 0.0070
# 1/1 [==============================] - 0s 654us/step - loss: 0.0069
# 1/1 [==============================] - 0s 636us/step - loss: 0.0074
# 1/1 [==============================] - 0s 690us/step - loss: 0.0051
# 1/1 [==============================] - 0s 633us/step - loss: 0.0048
# 1/1 [==============================] - 0s 620us/step - loss: 0.0054
# 1/1 [==============================] - 0s 627us/step - loss: 0.0057
# 1/1 [==============================] - 0s 647us/step - loss: 0.0057
# 1/1 [==============================] - 0s 616us/step - loss: 0.0057
# 1/1 [==============================] - 0s 634us/step - loss: 0.0057
# 1/1 [==============================] - 0s 713us/step - loss: 0.0057
# 1/1 [==============================] - 0s 744us/step - loss: 0.0058
# 1/1 [==============================] - 0s 619us/step - loss: 0.0058
# 1/1 [==============================] - 0s 584us/step - loss: 0.0051
# 1/1 [==============================] - 0s 633us/step - loss: 0.0055
# 1/1 [==============================] - 0s 751us/step - loss: 0.0048
# 1/1 [==============================] - 0s 971us/step - loss: 0.0080
# 1/1 [==============================] - 0s 585us/step - loss: 0.0063
# 1/1 [==============================] - 0s 622us/step - loss: 0.0068
# 1/1 [==============================] - 0s 935us/step - loss: 0.0081
# 1/1 [==============================] - 0s 793us/step - loss: 0.0062
# 1/1 [==============================] - 0s 820us/step - loss: 0.0052
# 1/1 [==============================] - 0s 643us/step - loss: 0.0064
# 1/1 [==============================] - 0s 670us/step - loss: 0.0065
# 1/1 [==============================] - 0s 782us/step - loss: 0.0060
# 1/1 [==============================] - 0s 726us/step - loss: 0.0053
# 1/1 [==============================] - 0s 887us/step - loss: 0.0053
# 1/1 [==============================] - 0s 560us/step - loss: 0.0056
# 1/1 [==============================] - 0s 755us/step - loss: 0.0056
# 1/1 [==============================] - 0s 677us/step - loss: 0.0058
# 1/1 [==============================] - 0s 919us/step - loss: 0.0059
# 1/1 [==============================] - 0s 607us/step - loss: 0.0052
# 1/1 [==============================] - 0s 811us/step - loss: 0.0052
# 1/1 [==============================] - 0s 617us/step - loss: 0.0054
# 1/1 [==============================] - 0s 763us/step - loss: 0.0055
# 1/1 [==============================] - 0s 586us/step - loss: 0.0051
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0083
# 1/1 [==============================] - 0s 904us/step - loss: 0.0054
# 1/1 [==============================] - 0s 620us/step - loss: 0.0053
# 1/1 [==============================] - 0s 600us/step - loss: 0.0051
# 1/1 [==============================] - 0s 646us/step - loss: 0.0066
# 1/1 [==============================] - 0s 855us/step - loss: 0.0052
# 1/1 [==============================] - 0s 838us/step - loss: 0.0052
# 1/1 [==============================] - 0s 640us/step - loss: 0.0055
# 1/1 [==============================] - 0s 887us/step - loss: 0.0054
# 1/1 [==============================] - 0s 679us/step - loss: 0.0056
# 1/1 [==============================] - 0s 618us/step - loss: 0.0055
# 1/1 [==============================] - 0s 649us/step - loss: 0.0054
# 1/1 [==============================] - 0s 626us/step - loss: 0.0052
# 1/1 [==============================] - 0s 623us/step - loss: 0.0052
# 1/1 [==============================] - 0s 674us/step - loss: 0.0052
# 1/1 [==============================] - 0s 596us/step - loss: 0.0052
# 1/1 [==============================] - 0s 642us/step - loss: 0.0052
# 1/1 [==============================] - 0s 619us/step - loss: 0.0059
# 1/1 [==============================] - 0s 750us/step - loss: 0.0055
# 1/1 [==============================] - 0s 680us/step - loss: 0.0054
# 1/1 [==============================] - 0s 695us/step - loss: 0.0056
# 1/1 [==============================] - 0s 636us/step - loss: 0.0055
# 1/1 [==============================] - 0s 670us/step - loss: 0.0055
# 1/1 [==============================] - 0s 763us/step - loss: 0.0070
# 1/1 [==============================] - 0s 682us/step - loss: 0.0051
# 1/1 [==============================] - 0s 634us/step - loss: 0.0056
# 1/1 [==============================] - 0s 618us/step - loss: 0.0059
# 1/1 [==============================] - 0s 709us/step - loss: 0.0052
# 1/1 [==============================] - 0s 761us/step - loss: 0.0064
# 1/1 [==============================] - 0s 593us/step - loss: 0.0056
# 1/1 [==============================] - 0s 627us/step - loss: 0.0056
# 1/1 [==============================] - 0s 635us/step - loss: 0.0056
# 1/1 [==============================] - 0s 914us/step - loss: 0.0056
# 1/1 [==============================] - 0s 646us/step - loss: 0.0056
# 1/1 [==============================] - 0s 638us/step - loss: 0.0062
# 1/1 [==============================] - 0s 675us/step - loss: 0.0065
# 1/1 [==============================] - 0s 672us/step - loss: 0.0064
# 1/1 [==============================] - 0s 771us/step - loss: 0.0056
# 1/1 [==============================] - 0s 878us/step - loss: 0.0055
# 1/1 [==============================] - 0s 915us/step - loss: 0.0070
# 1/1 [==============================] - 0s 882us/step - loss: 0.0057
# 1/1 [==============================] - 0s 776us/step - loss: 0.0052
# 1/1 [==============================] - 0s 864us/step - loss: 0.0060
# 1/1 [==============================] - 0s 765us/step - loss: 0.0087
# 1/1 [==============================] - 0s 722us/step - loss: 0.0064
# 1/1 [==============================] - 0s 651us/step - loss: 0.0052
# 1/1 [==============================] - 0s 633us/step - loss: 0.0054
# 1/1 [==============================] - 0s 628us/step - loss: 0.0051
# 1/1 [==============================] - 0s 616us/step - loss: 0.0062
# 1/1 [==============================] - 0s 609us/step - loss: 0.0055
# 1/1 [==============================] - 0s 668us/step - loss: 0.0055
# 1/1 [==============================] - 0s 622us/step - loss: 0.0064
# 1/1 [==============================] - 0s 736us/step - loss: 0.0059
# 1/1 [==============================] - 0s 673us/step - loss: 0.0056
# 1/1 [==============================] - 0s 618us/step - loss: 0.0054
# 1/1 [==============================] - 0s 926us/step - loss: 0.0054
# 1/1 [==============================] - 0s 756us/step - loss: 0.0058
# 1/1 [==============================] - 0s 726us/step - loss: 0.0068
# 1/1 [==============================] - 0s 759us/step - loss: 0.0063
# 1/1 [==============================] - 0s 791us/step - loss: 0.0063
# 1/1 [==============================] - 0s 614us/step - loss: 0.0074
# 1/1 [==============================] - 0s 635us/step - loss: 0.0090
# 1/1 [==============================] - 0s 620us/step - loss: 0.0097
# 1/1 [==============================] - 0s 815us/step - loss: 0.0091
# 1/1 [==============================] - 0s 630us/step - loss: 0.0113
# 1/1 [==============================] - 0s 707us/step - loss: 0.0121
# 1/1 [==============================] - 0s 638us/step - loss: 0.0052
# 1/1 [==============================] - 0s 609us/step - loss: 0.0057
# 1/1 [==============================] - 0s 947us/step - loss: 0.0079
# 1/1 [==============================] - 0s 593us/step - loss: 0.0062
# 1/1 [==============================] - 0s 615us/step - loss: 0.0064
# 1/1 [==============================] - 0s 594us/step - loss: 0.0065
# 1/1 [==============================] - 0s 670us/step - loss: 0.0066
# 1/1 [==============================] - 0s 746us/step - loss: 0.0070
# 1/1 [==============================] - 0s 593us/step - loss: 0.0066
# 1/1 [==============================] - 0s 717us/step - loss: 0.0077
# 1/1 [==============================] - 0s 596us/step - loss: 0.0086
# 1/1 [==============================] - 0s 648us/step - loss: 0.0085
# 1/1 [==============================] - 0s 687us/step - loss: 0.0085
# 1/1 [==============================] - 0s 650us/step - loss: 0.0053
# 1/1 [==============================] - 0s 914us/step - loss: 0.0079
# 1/1 [==============================] - 0s 651us/step - loss: 0.0050
# 1/1 [==============================] - 0s 837us/step - loss: 0.0048
# 1/1 [==============================] - 0s 641us/step - loss: 0.0075
# 1/1 [==============================] - 0s 606us/step - loss: 0.0066
# 1/1 [==============================] - 0s 639us/step - loss: 0.0050
# 1/1 [==============================] - 0s 802us/step - loss: 0.0087
# 1/1 [==============================] - 0s 609us/step - loss: 0.0069
# 1/1 [==============================] - 0s 766us/step - loss: 0.0077
# 1/1 [==============================] - 0s 616us/step - loss: 0.0086
# 1/1 [==============================] - 0s 797us/step - loss: 0.0084
# 1/1 [==============================] - 0s 653us/step - loss: 0.0090
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0050
# 1/1 [==============================] - 0s 930us/step - loss: 0.0048
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0048
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0075
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0137
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0094
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0088
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0051
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0060
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0059
# 1/1 [==============================] - 0s 976us/step - loss: 0.0058
# 1/1 [==============================] - 0s 992us/step - loss: 0.0074
# 1/1 [==============================] - 0s 964us/step - loss: 0.0065
# 1/1 [==============================] - 0s 710us/step - loss: 0.0056
# 1/1 [==============================] - 0s 601us/step - loss: 0.0052
# 1/1 [==============================] - 0s 652us/step - loss: 0.0050
# 1/1 [==============================] - 0s 609us/step - loss: 0.0051
# 1/1 [==============================] - 0s 622us/step - loss: 0.0085
# 1/1 [==============================] - 0s 689us/step - loss: 0.0084
# 1/1 [==============================] - 0s 660us/step - loss: 0.0084
# 1/1 [==============================] - 0s 701us/step - loss: 0.0053
# 1/1 [==============================] - 0s 607us/step - loss: 0.0052
# 1/1 [==============================] - 0s 567us/step - loss: 0.0074
# 1/1 [==============================] - 0s 612us/step - loss: 0.0075
# 1/1 [==============================] - 0s 680us/step - loss: 0.0074
# 1/1 [==============================] - 0s 647us/step - loss: 0.0070
# 1/1 [==============================] - 0s 685us/step - loss: 0.0072
# 1/1 [==============================] - 0s 654us/step - loss: 0.0058
# 1/1 [==============================] - 0s 636us/step - loss: 0.0047
# 1/1 [==============================] - 0s 616us/step - loss: 0.0083
# 1/1 [==============================] - 0s 585us/step - loss: 0.0099
# 1/1 [==============================] - 0s 628us/step - loss: 0.0078
# 1/1 [==============================] - 0s 615us/step - loss: 0.0076
# 1/1 [==============================] - 0s 609us/step - loss: 0.0071
# 1/1 [==============================] - 0s 599us/step - loss: 0.0054
# 1/1 [==============================] - 0s 868us/step - loss: 0.0053
# 1/1 [==============================] - 0s 642us/step - loss: 0.0069
# 1/1 [==============================] - 0s 754us/step - loss: 0.0073
# 1/1 [==============================] - 0s 633us/step - loss: 0.0071
# 1/1 [==============================] - 0s 737us/step - loss: 0.0053
# 1/1 [==============================] - 0s 697us/step - loss: 0.0056
# 1/1 [==============================] - 0s 632us/step - loss: 0.0059
# 1/1 [==============================] - 0s 611us/step - loss: 0.0058
# 1/1 [==============================] - 0s 589us/step - loss: 0.0052
# 1/1 [==============================] - 0s 725us/step - loss: 0.0058
# 1/1 [==============================] - 0s 600us/step - loss: 0.0062
# 1/1 [==============================] - 0s 760us/step - loss: 0.0072
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0070
# 1/1 [==============================] - 0s 614us/step - loss: 0.0081
# 1/1 [==============================] - 0s 682us/step - loss: 0.0085
# 1/1 [==============================] - 0s 743us/step - loss: 0.0058
# 1/1 [==============================] - 0s 690us/step - loss: 0.0058
# 1/1 [==============================] - 0s 634us/step - loss: 0.0057
# 1/1 [==============================] - 0s 599us/step - loss: 0.0053
# 1/1 [==============================] - 0s 590us/step - loss: 0.0070
# 1/1 [==============================] - 0s 648us/step - loss: 0.0063
# 1/1 [==============================] - 0s 643us/step - loss: 0.0058
# 1/1 [==============================] - 0s 735us/step - loss: 0.0052
# 1/1 [==============================] - 0s 620us/step - loss: 0.0053
# 1/1 [==============================] - 0s 633us/step - loss: 0.0051
# 1/1 [==============================] - 0s 611us/step - loss: 0.0052
# 1/1 [==============================] - 0s 922us/step - loss: 0.0052
# 1/1 [==============================] - 0s 574us/step - loss: 0.0052
# 1/1 [==============================] - 0s 605us/step - loss: 0.0050
# 1/1 [==============================] - 0s 615us/step - loss: 0.0051
# 1/1 [==============================] - 0s 651us/step - loss: 0.0051
# 1/1 [==============================] - 0s 613us/step - loss: 0.0051
# 1/1 [==============================] - 0s 610us/step - loss: 0.0054
# 1/1 [==============================] - 0s 669us/step - loss: 0.0089
# 1/1 [==============================] - 0s 591us/step - loss: 0.0061
# 1/1 [==============================] - 0s 601us/step - loss: 0.0051
# 1/1 [==============================] - 0s 627us/step - loss: 0.0055
# 1/1 [==============================] - 0s 739us/step - loss: 0.0056
# 1/1 [==============================] - 0s 869us/step - loss: 0.0069
# 1/1 [==============================] - 0s 608us/step - loss: 0.0063
# 1/1 [==============================] - 0s 606us/step - loss: 0.0056
# 1/1 [==============================] - 0s 577us/step - loss: 0.0064
# 1/1 [==============================] - 0s 580us/step - loss: 0.0051
# 1/1 [==============================] - 0s 695us/step - loss: 0.0051
# 1/1 [==============================] - 0s 669us/step - loss: 0.0052
# 1/1 [==============================] - 0s 627us/step - loss: 0.0051
# 1/1 [==============================] - 0s 703us/step - loss: 0.0090
# 1/1 [==============================] - 0s 624us/step - loss: 0.0077
# 1/1 [==============================] - 0s 715us/step - loss: 0.0074
# 1/1 [==============================] - 0s 591us/step - loss: 0.0076
# 1/1 [==============================] - 0s 600us/step - loss: 0.0066
# 1/1 [==============================] - 0s 631us/step - loss: 0.0062
# 1/1 [==============================] - 0s 621us/step - loss: 0.0058
# 1/1 [==============================] - 0s 745us/step - loss: 0.0055
# 1/1 [==============================] - 0s 578us/step - loss: 0.0056
# 1/1 [==============================] - 0s 624us/step - loss: 0.0054
# 1/1 [==============================] - 0s 638us/step - loss: 0.0055
# 1/1 [==============================] - 0s 632us/step - loss: 0.0055
# 1/1 [==============================] - 0s 630us/step - loss: 0.0066
# 1/1 [==============================] - 0s 937us/step - loss: 0.0090
# 1/1 [==============================] - 0s 602us/step - loss: 0.0070
# 1/1 [==============================] - 0s 593us/step - loss: 0.0059
# 1/1 [==============================] - 0s 715us/step - loss: 0.0062
# 1/1 [==============================] - 0s 582us/step - loss: 0.0053
# 1/1 [==============================] - 0s 583us/step - loss: 0.0058
# 1/1 [==============================] - 0s 756us/step - loss: 0.0055
# 1/1 [==============================] - 0s 606us/step - loss: 0.0059
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0091
# 1/1 [==============================] - 0s 615us/step - loss: 0.0098
# 1/1 [==============================] - 0s 667us/step - loss: 0.0100
# 1/1 [==============================] - 0s 601us/step - loss: 0.0098
# 1/1 [==============================] - 0s 706us/step - loss: 0.0062
# 1/1 [==============================] - 0s 630us/step - loss: 0.0060
# 1/1 [==============================] - 0s 928us/step - loss: 0.0054
# 1/1 [==============================] - 0s 610us/step - loss: 0.0055
# 1/1 [==============================] - 0s 587us/step - loss: 0.0058
# 1/1 [==============================] - 0s 678us/step - loss: 0.0053
# 1/1 [==============================] - 0s 742us/step - loss: 0.0059
# 1/1 [==============================] - 0s 698us/step - loss: 0.0059
# 1/1 [==============================] - 0s 611us/step - loss: 0.0076
# 1/1 [==============================] - 0s 723us/step - loss: 0.0091
# 1/1 [==============================] - 0s 621us/step - loss: 0.0108
# 1/1 [==============================] - 0s 613us/step - loss: 0.0062
# 1/1 [==============================] - 0s 717us/step - loss: 0.0054
# 1/1 [==============================] - 0s 659us/step - loss: 0.0058
# 1/1 [==============================] - 0s 731us/step - loss: 0.0059
# 1/1 [==============================] - 0s 627us/step - loss: 0.0058
# 1/1 [==============================] - 0s 892us/step - loss: 0.0061
# 1/1 [==============================] - 0s 633us/step - loss: 0.0062
# 1/1 [==============================] - 0s 723us/step - loss: 0.0053
# 1/1 [==============================] - 0s 624us/step - loss: 0.0054
# 1/1 [==============================] - 0s 779us/step - loss: 0.0060
# 1/1 [==============================] - 0s 591us/step - loss: 0.0059
# 1/1 [==============================] - 0s 591us/step - loss: 0.0049
# 1/1 [==============================] - 0s 646us/step - loss: 0.0064
# 1/1 [==============================] - 0s 597us/step - loss: 0.0054
# 1/1 [==============================] - 0s 588us/step - loss: 0.0055
# 1/1 [==============================] - 0s 634us/step - loss: 0.0066
# 1/1 [==============================] - 0s 639us/step - loss: 0.0065
# 1/1 [==============================] - 0s 567us/step - loss: 0.0050
# 1/1 [==============================] - 0s 647us/step - loss: 0.0063
# 1/1 [==============================] - 0s 575us/step - loss: 0.0061
# 1/1 [==============================] - 0s 733us/step - loss: 0.0051
# 1/1 [==============================] - 0s 600us/step - loss: 0.0050
# 1/1 [==============================] - 0s 588us/step - loss: 0.0052
# 1/1 [==============================] - 0s 598us/step - loss: 0.0057
# 1/1 [==============================] - 0s 601us/step - loss: 0.0056
# 1/1 [==============================] - 0s 717us/step - loss: 0.0058
# 1/1 [==============================] - 0s 726us/step - loss: 0.0060
# 1/1 [==============================] - 0s 703us/step - loss: 0.0081
# 1/1 [==============================] - 0s 653us/step - loss: 0.0066
# 1/1 [==============================] - 0s 637us/step - loss: 0.0059
# 1/1 [==============================] - 0s 777us/step - loss: 0.0084
# 1/1 [==============================] - 0s 677us/step - loss: 0.0064
# 1/1 [==============================] - 0s 634us/step - loss: 0.0069
# 1/1 [==============================] - 0s 683us/step - loss: 0.0061
# 1/1 [==============================] - 0s 705us/step - loss: 0.0054
# 1/1 [==============================] - 0s 637us/step - loss: 0.0054
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0049
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0083
# 1/1 [==============================] - 0s 747us/step - loss: 0.0058
# 1/1 [==============================] - 0s 749us/step - loss: 0.0089
# 1/1 [==============================] - 0s 586us/step - loss: 0.0056
# 1/1 [==============================] - 0s 683us/step - loss: 0.0057
# 1/1 [==============================] - 0s 828us/step - loss: 0.0057
# 1/1 [==============================] - 0s 820us/step - loss: 0.0057
# 1/1 [==============================] - 0s 621us/step - loss: 0.0056
# 1/1 [==============================] - 0s 591us/step - loss: 0.0057
# 1/1 [==============================] - 0s 582us/step - loss: 0.0050
# 1/1 [==============================] - 0s 614us/step - loss: 0.0057
# 1/1 [==============================] - 0s 590us/step - loss: 0.0054
# 1/1 [==============================] - 0s 665us/step - loss: 0.0054
# 1/1 [==============================] - 0s 605us/step - loss: 0.0100
# 1/1 [==============================] - 0s 614us/step - loss: 0.0074
# 1/1 [==============================] - 0s 654us/step - loss: 0.0085
# 1/1 [==============================] - 0s 818us/step - loss: 0.0057
# 1/1 [==============================] - 0s 588us/step - loss: 0.0064
# 1/1 [==============================] - 0s 583us/step - loss: 0.0062
# 1/1 [==============================] - 0s 786us/step - loss: 0.0098
# 1/1 [==============================] - 0s 762us/step - loss: 0.0066
# 1/1 [==============================] - 0s 590us/step - loss: 0.0075
# 1/1 [==============================] - 0s 623us/step - loss: 0.0093
# 1/1 [==============================] - 0s 620us/step - loss: 0.0054
# 1/1 [==============================] - 0s 682us/step - loss: 0.0052
# 1/1 [==============================] - 0s 692us/step - loss: 0.0053
# 1/1 [==============================] - 0s 742us/step - loss: 0.0054
# 1/1 [==============================] - 0s 635us/step - loss: 0.0052
# 1/1 [==============================] - 0s 611us/step - loss: 0.0048
# 1/1 [==============================] - 0s 739us/step - loss: 0.0059
# 1/1 [==============================] - 0s 728us/step - loss: 0.0056
# 1/1 [==============================] - 0s 730us/step - loss: 0.0060
# 1/1 [==============================] - 0s 812us/step - loss: 0.0058
# 1/1 [==============================] - 0s 624us/step - loss: 0.0093
# 1/1 [==============================] - 0s 585us/step - loss: 0.0056
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0058
# 1/1 [==============================] - 0s 617us/step - loss: 0.0074
# 1/1 [==============================] - 0s 600us/step - loss: 0.0061
# 1/1 [==============================] - 0s 669us/step - loss: 0.0050
# 1/1 [==============================] - 0s 666us/step - loss: 0.0050
# 1/1 [==============================] - 0s 610us/step - loss: 0.0054
# 1/1 [==============================] - 0s 599us/step - loss: 0.0061
# 1/1 [==============================] - 0s 744us/step - loss: 0.0062
# 1/1 [==============================] - 0s 596us/step - loss: 0.0057
# 1/1 [==============================] - 0s 659us/step - loss: 0.0059
# 1/1 [==============================] - 0s 592us/step - loss: 0.0060
# 1/1 [==============================] - 0s 630us/step - loss: 0.0078
# 1/1 [==============================] - 0s 664us/step - loss: 0.0072
# 1/1 [==============================] - 0s 583us/step - loss: 0.0068
# 1/1 [==============================] - 0s 654us/step - loss: 0.0061
# 1/1 [==============================] - 0s 592us/step - loss: 0.0059
# 1/1 [==============================] - 0s 583us/step - loss: 0.0052
# 1/1 [==============================] - 0s 814us/step - loss: 0.0060
# 1/1 [==============================] - 0s 602us/step - loss: 0.0056
# 1/1 [==============================] - 0s 584us/step - loss: 0.0060
# 1/1 [==============================] - 0s 675us/step - loss: 0.0054
# 1/1 [==============================] - 0s 560us/step - loss: 0.0058
# 1/1 [==============================] - 0s 621us/step - loss: 0.0071
# 1/1 [==============================] - 0s 598us/step - loss: 0.0061
# 1/1 [==============================] - 0s 666us/step - loss: 0.0049
# 1/1 [==============================] - 0s 608us/step - loss: 0.0068
# 1/1 [==============================] - 0s 608us/step - loss: 0.0094
# 1/1 [==============================] - 0s 702us/step - loss: 0.0105
# 1/1 [==============================] - 0s 627us/step - loss: 0.0058
# 1/1 [==============================] - 0s 602us/step - loss: 0.0054
# 1/1 [==============================] - 0s 644us/step - loss: 0.0054
# 1/1 [==============================] - 0s 883us/step - loss: 0.0054
# 1/1 [==============================] - 0s 841us/step - loss: 0.0051
# 1/1 [==============================] - 0s 659us/step - loss: 0.0053
# 1/1 [==============================] - 0s 606us/step - loss: 0.0082
# 1/1 [==============================] - 0s 994us/step - loss: 0.0049
# 1/1 [==============================] - 0s 760us/step - loss: 0.0070
# 1/1 [==============================] - 0s 800us/step - loss: 0.0072
# 1/1 [==============================] - 0s 679us/step - loss: 0.0138
# 1/1 [==============================] - 0s 649us/step - loss: 0.0151
# 1/1 [==============================] - 0s 627us/step - loss: 0.0132
# 1/1 [==============================] - 0s 645us/step - loss: 0.0057
# 1/1 [==============================] - 0s 666us/step - loss: 0.0068
# 1/1 [==============================] - 0s 623us/step - loss: 0.0089
# 1/1 [==============================] - 0s 681us/step - loss: 0.0064
# 1/1 [==============================] - 0s 663us/step - loss: 0.0091
# 1/1 [==============================] - 0s 611us/step - loss: 0.0118
# 1/1 [==============================] - 0s 570us/step - loss: 0.0121
# 1/1 [==============================] - 0s 868us/step - loss: 0.0075
# 1/1 [==============================] - 0s 678us/step - loss: 0.0076
# 1/1 [==============================] - 0s 637us/step - loss: 0.0073
# 1/1 [==============================] - 0s 593us/step - loss: 0.0053
# 1/1 [==============================] - 0s 647us/step - loss: 0.0060
# 1/1 [==============================] - 0s 621us/step - loss: 0.0059
# 1/1 [==============================] - 0s 590us/step - loss: 0.0057
# 1/1 [==============================] - 0s 672us/step - loss: 0.0063
# 1/1 [==============================] - 0s 682us/step - loss: 0.0060
# 1/1 [==============================] - 0s 770us/step - loss: 0.0063
# 1/1 [==============================] - 0s 657us/step - loss: 0.0084
# 1/1 [==============================] - 0s 584us/step - loss: 0.0124
# 1/1 [==============================] - 0s 729us/step - loss: 0.0110
# 1/1 [==============================] - 0s 610us/step - loss: 0.0110
# 1/1 [==============================] - 0s 726us/step - loss: 0.0096
# 1/1 [==============================] - 0s 622us/step - loss: 0.0079
# 1/1 [==============================] - 0s 584us/step - loss: 0.0079
# 1/1 [==============================] - 0s 954us/step - loss: 0.0052
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0054
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0108
# 1/1 [==============================] - 0s 652us/step - loss: 0.0066
# 1/1 [==============================] - 0s 634us/step - loss: 0.0085
# 1/1 [==============================] - 0s 712us/step - loss: 0.0076
# 1/1 [==============================] - 0s 685us/step - loss: 0.0067
# 1/1 [==============================] - 0s 712us/step - loss: 0.0072
# 1/1 [==============================] - 0s 653us/step - loss: 0.0075
# 1/1 [==============================] - 0s 827us/step - loss: 0.0073
# 1/1 [==============================] - 0s 586us/step - loss: 0.0058
# 1/1 [==============================] - 0s 693us/step - loss: 0.0059
# 1/1 [==============================] - 0s 668us/step - loss: 0.0055
# 1/1 [==============================] - 0s 623us/step - loss: 0.0104
# 1/1 [==============================] - 0s 769us/step - loss: 0.0129
# 1/1 [==============================] - 0s 680us/step - loss: 0.0157
# 1/1 [==============================] - 0s 608us/step - loss: 0.0092
# 1/1 [==============================] - 0s 620us/step - loss: 0.0139
# 1/1 [==============================] - 0s 597us/step - loss: 0.0131
# 1/1 [==============================] - 0s 698us/step - loss: 0.0136
# 1/1 [==============================] - 0s 576us/step - loss: 0.0052
# 1/1 [==============================] - 0s 643us/step - loss: 0.0051
# 1/1 [==============================] - 0s 725us/step - loss: 0.0059
# 1/1 [==============================] - 0s 550us/step - loss: 0.0078
# 1/1 [==============================] - 0s 656us/step - loss: 0.0078
# 1/1 [==============================] - 0s 714us/step - loss: 0.0078
# 1/1 [==============================] - 0s 625us/step - loss: 0.0073
# 1/1 [==============================] - 0s 623us/step - loss: 0.0069
# 1/1 [==============================] - 0s 747us/step - loss: 0.0067
# 1/1 [==============================] - 0s 637us/step - loss: 0.0067
# 1/1 [==============================] - 0s 969us/step - loss: 0.0064
# 1/1 [==============================] - 0s 903us/step - loss: 0.0064
# 1/1 [==============================] - 0s 775us/step - loss: 0.0066
# 1/1 [==============================] - 0s 648us/step - loss: 0.0053
# 1/1 [==============================] - 0s 617us/step - loss: 0.0052
# 1/1 [==============================] - 0s 609us/step - loss: 0.0051
# 1/1 [==============================] - 0s 614us/step - loss: 0.0047
# 1/1 [==============================] - 0s 675us/step - loss: 0.0052
# 1/1 [==============================] - 0s 629us/step - loss: 0.0048
# 1/1 [==============================] - 0s 619us/step - loss: 0.0054
# 1/1 [==============================] - 0s 652us/step - loss: 0.0052
# 1/1 [==============================] - 0s 777us/step - loss: 0.0053
# 1/1 [==============================] - 0s 672us/step - loss: 0.0101
# 1/1 [==============================] - 0s 763us/step - loss: 0.0068
# 1/1 [==============================] - 0s 706us/step - loss: 0.0065
# 1/1 [==============================] - 0s 757us/step - loss: 0.0071
# 1/1 [==============================] - 0s 670us/step - loss: 0.0074
# 1/1 [==============================] - 0s 714us/step - loss: 0.0076
# 1/1 [==============================] - 0s 631us/step - loss: 0.0062
# 1/1 [==============================] - 0s 681us/step - loss: 0.0056
# 1/1 [==============================] - 0s 652us/step - loss: 0.0091
# 1/1 [==============================] - 0s 827us/step - loss: 0.0064
# 1/1 [==============================] - 0s 640us/step - loss: 0.0091
# 1/1 [==============================] - 0s 638us/step - loss: 0.0093
# 1/1 [==============================] - 0s 639us/step - loss: 0.0106
# 1/1 [==============================] - 0s 675us/step - loss: 0.0136
# 1/1 [==============================] - 0s 615us/step - loss: 0.0129
# 1/1 [==============================] - 0s 771us/step - loss: 0.0164
# 1/1 [==============================] - 0s 633us/step - loss: 0.0131
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0122
# 1/1 [==============================] - 0s 657us/step - loss: 0.0129
# 1/1 [==============================] - 0s 589us/step - loss: 0.0138
# 1/1 [==============================] - 0s 616us/step - loss: 0.0099
# 1/1 [==============================] - 0s 622us/step - loss: 0.0090
# 1/1 [==============================] - 0s 750us/step - loss: 0.0088
# 1/1 [==============================] - 0s 616us/step - loss: 0.0087
# 1/1 [==============================] - 0s 831us/step - loss: 0.0101
# 1/1 [==============================] - 0s 690us/step - loss: 0.0107
# 1/1 [==============================] - 0s 592us/step - loss: 0.0081
# 1/1 [==============================] - 0s 593us/step - loss: 0.0081
# 1/1 [==============================] - 0s 679us/step - loss: 0.0083
# 1/1 [==============================] - 0s 617us/step - loss: 0.0083
# 1/1 [==============================] - 0s 585us/step - loss: 0.0084
# 1/1 [==============================] - 0s 617us/step - loss: 0.0151
# 1/1 [==============================] - 0s 823us/step - loss: 0.0069
# 1/1 [==============================] - 0s 619us/step - loss: 0.0071
# 1/1 [==============================] - 0s 640us/step - loss: 0.0067
# 1/1 [==============================] - 0s 663us/step - loss: 0.0068
# 1/1 [==============================] - 0s 613us/step - loss: 0.0072
# 1/1 [==============================] - 0s 781us/step - loss: 0.0071
# 1/1 [==============================] - 0s 598us/step - loss: 0.0070
# 1/1 [==============================] - 0s 618us/step - loss: 0.0070
# 1/1 [==============================] - 0s 670us/step - loss: 0.0139
# 1/1 [==============================] - 0s 632us/step - loss: 0.0085
# 1/1 [==============================] - 0s 591us/step - loss: 0.0068
# 1/1 [==============================] - 0s 623us/step - loss: 0.0073
# 1/1 [==============================] - 0s 598us/step - loss: 0.0071
# 1/1 [==============================] - 0s 612us/step - loss: 0.0089
# 1/1 [==============================] - 0s 587us/step - loss: 0.0081
# 1/1 [==============================] - 0s 664us/step - loss: 0.0081
# 1/1 [==============================] - 0s 615us/step - loss: 0.0080
# 1/1 [==============================] - 0s 741us/step - loss: 0.0070
# 1/1 [==============================] - 0s 618us/step - loss: 0.0117
# 1/1 [==============================] - 0s 633us/step - loss: 0.0180
# 1/1 [==============================] - 0s 682us/step - loss: 0.0140
# 1/1 [==============================] - 0s 713us/step - loss: 0.0186
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0161
# 1/1 [==============================] - 0s 607us/step - loss: 0.0185
# 1/1 [==============================] - 0s 700us/step - loss: 0.0128
# 1/1 [==============================] - 0s 776us/step - loss: 0.0122
# 1/1 [==============================] - 0s 618us/step - loss: 0.0117
# 1/1 [==============================] - 0s 595us/step - loss: 0.0120
# 1/1 [==============================] - 0s 613us/step - loss: 0.0120
# 1/1 [==============================] - 0s 619us/step - loss: 0.0055
# 1/1 [==============================] - 0s 697us/step - loss: 0.0050
# 1/1 [==============================] - 0s 724us/step - loss: 0.0061
# 1/1 [==============================] - 0s 770us/step - loss: 0.0070
# 1/1 [==============================] - 0s 736us/step - loss: 0.0051
# 1/1 [==============================] - 0s 843us/step - loss: 0.0050
# 1/1 [==============================] - 0s 617us/step - loss: 0.0084
# 1/1 [==============================] - 0s 604us/step - loss: 0.0050
# 1/1 [==============================] - 0s 620us/step - loss: 0.0050
# 1/1 [==============================] - 0s 860us/step - loss: 0.0075
# 1/1 [==============================] - 0s 584us/step - loss: 0.0049
# 1/1 [==============================] - 0s 802us/step - loss: 0.0051
# 1/1 [==============================] - 0s 687us/step - loss: 0.0053
# 1/1 [==============================] - 0s 609us/step - loss: 0.0052
# 1/1 [==============================] - 0s 656us/step - loss: 0.0051
# 1/1 [==============================] - 0s 585us/step - loss: 0.0048
# 1/1 [==============================] - 0s 615us/step - loss: 0.0049
# 1/1 [==============================] - 0s 700us/step - loss: 0.0049
# 1/1 [==============================] - 0s 908us/step - loss: 0.0049
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0048
# 1/1 [==============================] - 0s 645us/step - loss: 0.0048
# 1/1 [==============================] - 0s 629us/step - loss: 0.0081
# 1/1 [==============================] - 0s 879us/step - loss: 0.0048
# 1/1 [==============================] - 0s 685us/step - loss: 0.0049
# 1/1 [==============================] - 0s 626us/step - loss: 0.0050
# 1/1 [==============================] - 0s 678us/step - loss: 0.0051
# 1/1 [==============================] - 0s 714us/step - loss: 0.0056
# 1/1 [==============================] - 0s 722us/step - loss: 0.0059
# 1/1 [==============================] - 0s 602us/step - loss: 0.0058
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0066
# 1/1 [==============================] - 0s 661us/step - loss: 0.0047
# 1/1 [==============================] - 0s 865us/step - loss: 0.0048
# 1/1 [==============================] - 0s 628us/step - loss: 0.0050
# 1/1 [==============================] - 0s 608us/step - loss: 0.0053
# 1/1 [==============================] - 0s 605us/step - loss: 0.0052
# 1/1 [==============================] - 0s 823us/step - loss: 0.0049
# 1/1 [==============================] - 0s 767us/step - loss: 0.0056
# 1/1 [==============================] - 0s 631us/step - loss: 0.0056
# 1/1 [==============================] - 0s 762us/step - loss: 0.0056
# 1/1 [==============================] - 0s 606us/step - loss: 0.0056
# The list of rec. error contains  60 batches of rec. errors

# %% [markdown]
# Above we can see, that it contains 60 batches and almost all of them includes 10 elements. Recall that the total number of images of the training dataset was 295. Hence in total we should have 295*2=590 error values. Let's convert it into a 590-length list.

# %%
total_rec_error_list = [item for sublist in total_rec_error for item in sublist]
print(len(total_rec_error_list))
# Out:
# 590

# %%
na_average_recon_error = np.mean(np.array(total_rec_error_list))  
na_stdev_recon_error = np.std(np.array(total_rec_error_list)) 
min_prob = np.min(total_rec_error_list)
max_prob = np.max(total_rec_error_list)
print("THIS IS FOR THE TRAINING (NON-ANOMALY) IMAGES\n")
print("The average of the errors list is: ", na_average_recon_error)
print("The standard deviation of the errors list is: ", na_stdev_recon_error)
print("The min value of the errors list is: ", min_prob)
print("The max value of the errors list is: ", max_prob)
# Out:
# THIS IS FOR THE TRAINING (NON-ANOMALY) IMAGES
#
# The average of the errors list is:  0.00686699018608463
# The standard deviation of the errors list is:  0.002277244860838618
# The min value of the errors list is:  0.004714467562735081
# The max value of the errors list is:  0.018583422526717186

# %% [markdown]
# Above it can be seen that computing the model.evaluate_generator() function does NOT output the same as computing the error of each image one by one. We will use this last approach, the one by one error computation.

# %% [markdown]
# Gaphically, the distribution of the reconstruction error values is shown below:

# %%
val = 0. # this is the value where you want the data to appear on the y-axis.
plt.plot(total_rec_error_list, np.zeros_like(total_rec_error_list) + val, 'x')
plt.show()

# %% [markdown]
# Or displying in a histogram way:

# %%
bins = np.linspace(0.003, 0.025, 50)
plt.hist(total_rec_error_list, bins, alpha=0.5, label='errors non-anomalies')
plt.legend(loc='upper right')

# Calculate average and standard deviation
average = np.mean(total_rec_error_list)
std = np.std(total_rec_error_list)

# Plot average line
plt.axvline(x=average, color='red', linestyle='--', label='Average')

# Plot lines for standard deviation
plt.axvline(x=average + std, color='black', linestyle=':', label='Average + Std')
plt.axvline(x=average - std, color='black', linestyle=':', label='Average - Std')

plt.legend()

plt.show()

# %% [markdown]
# # Checking the reconstruction of one sample

# %%
images_in_batch, images_in_batch2 = next(train_crops)           #As for each next step of the "train_crops" generator it exists one batch of the augmented and one batch of the orignial images, we perform twice the calc_recon_error() function
batch_input_images1 = images_in_batch[0]
single_img  = batch_input_images1[0]
single_img = single_img[np.newaxis, :,:,:]
reconstruction = model.predict([[single_img]])

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.title("input image")
plt.imshow(single_img[0])
plt.subplot(122)
plt.title("reconstructed image")
plt.imshow(reconstruction[0])
plt.show()

# %% [markdown]
# # Function to check if an image contains anomalies

# %% [markdown]
# Based on the previously found histogram, its average and its standard deviation values, it can be built a function that maps the reconstruction error to a probability value of an image being considered as an anomaly or not.
#
# If the a given reconstruction value is outside the range of the standard deviation sum and subtraction to the average values, shown in the plot above, then that reconstruction error has more than 50% chance to be considered as an anomaly image.

# %%
def ranges_mapper(value, leftMin, leftMax, rightMin, rightMax):
    # Figure out how 'wide' each range is
    leftSpan = leftMax - leftMin
    rightSpan = rightMax - rightMin

    # Convert the left range into a 0-1 range (float)
    valueScaled = float(value - leftMin) / float(leftSpan)

    # Convert the 0-1 range into a value in the right range.
    return rightMin + (valueScaled * rightSpan)

# %%
def map_error2prob(value):
    # Calculate the mean and standard deviation
    mean = na_average_recon_error
    std_dev = na_stdev_recon_error
    aux_score = value - mean
    prob_score = ranges_mapper(abs(aux_score), 0, std_dev, 0, 50)
    if prob_score<0:
        prob_score = 0
    if prob_score>100:
        prob_score = 100
    return prob_score

# %% [markdown]
# Testing a reconstruction error. Verifying that given some reconstruction error, the probability value is the one we expect.

# %%
print(map_error2prob(na_average_recon_error + na_stdev_recon_error))
# Out:
# 50.000000000000014

# %%
def map_error2prob_list(input_list):
    # Calculate the mean and standard deviation
    mean = na_average_recon_error
    std_dev = na_stdev_recon_error
    prob_score_list = []
    for i in range (len(input_list)):
        aux_score = input_list[i] - mean
        prob_score = ranges_mapper(abs(aux_score), 0, std_dev, 0, 50)
        if prob_score<0:
            prob_score = 0
        if prob_score>100:
            prob_score = 100
        prob_score_list.append(prob_score)
    return prob_score_list

# %% [markdown]
# # Understanding the validation generator

# %% [markdown]
# We will use the validation data set to find the best threshold value for predicting an image as anomaly or non-anomaly.

# %%
print("the number of batches of this generator is: ", len(validation_generator_for_threshold))
# Out:
# the number of batches of this generator is:  3

# %%
images_in_batch, images_labels = next(val_crops_for_threshold)

# %%
print(len(images_in_batch))
print(len(images_labels))
# Out:
# 10
# 10

# %% [markdown]
# Above we see two batches of size 10. As expected. One corresponds to the images and the other one to the labels of the images

# %%
single_image = images_in_batch[0]
label_img = images_labels[0]
print(single_image.shape)
print(label_img)
# Out:
# (160, 128, 3)
# 0.0

# %%
plt.imshow(single_image)
